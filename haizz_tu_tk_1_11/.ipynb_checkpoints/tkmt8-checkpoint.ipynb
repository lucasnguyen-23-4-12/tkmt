# %% [markdown]
# # ĐỀ KIỂM TRA CUỐI KỲ
# ## Học phần: Tối ưu hoá cho Khoa học dữ liệu
# ## Ngày: 16/12/2023
# ## Lớp: DHKHDL17A. Thời gian: 75 phút

# %% [markdown]
# Tên: Trương Thanh Hướng </br>
# MSSV: 21108531 </br>
# stt: 18

# %% [markdown]
# Câu 1. (6 điểm) Cho ma trận $A=\begin{bmatrix}1 & 0\\ 0 & -4 \end{bmatrix}$ và vector $b=(2;2)$. Xét bài toán tối ưu sau
# $$\min_{x\in\mathbb{R}^2}f(x)=\dfrac{1}{2}\|Ax-b\|_2^2.$$

# %% [markdown]
# a) (2 điểm) Xác định điểm tối ưu $x^*$ và giá trị tối ưu $p^*$ của bài toán trên.
#
# b) (2 điểm) Sử dụng thuật toán Gradient Descent, với giá trị $x$ ban đầu là $x^{(0)}=(-1;2)$, sử dụng learning rate lần lượt là $\dfrac{1}{7}$ và $\dfrac{1}{10}$ và thực hiện tối đa $100$ vòng lặp. In ra giá trị của $x^{(k)}$, $f(x^{(k)})$ tương ứng sau mỗi vòng lặp $k$ và vẽ đồ thị biểu thị cho sai số $|f(x^{(k)})-p^*|$ trong cả hai trường hợp của learning rate. Từ đó hãy đưa ra kết luận về sự hội tụ của thuật toán Gradient Descent trong từng trường hợp của learning rate.
#
# c) (1 điểm) Tìm điều kiện cụ thể cho learning rate để thuật toán Gradient Descent của bài toán trên hội tụ.
#
# d) (1 điểm) Trả lời câu a) với ma trận $A=\begin{bmatrix}1 & -2\\ 2 & -4 \end{bmatrix}$ và vector $b=(2;2)$.

# %%
import autograd.numpy as np
from autograd import grad
import matplotlib.pyplot as plt

# %%
def create_least_squares_problem(A, b):
    def f(x):
        r = A @ x - b
        return 0.5 * np.dot(r, r)
    return f

# %%
def gradient_descent(f, grad_f, x0, lr, max_iter):
    x = x0.copy()
    xs, fs = [x.copy()], [f(x)]

    print(f"\n=== Gradient Descent (lr = {lr}) ===")
    for k in range(max_iter):
        x = x - lr * grad_f(x)
        fx = f(x)
        xs.append(x.copy())
        fs.append(fx)

        print(f"Iter {k+1:3d}: x = {x}, f(x) = {fx:.6f}")

    return np.array(xs), np.array(fs)

# %%
def gd_convergence_condition(A):
    """
    Với f(x)=1/2||Ax-b||^2
    Hessian = A^T A
    GD hội tụ nếu 0 < lr < 2 / lambda_max(A^T A)
    """
    H = A.T @ A
    eigvals = np.linalg.eigvals(H)
    L = np.max(eigvals).real
    return 2 / L

# %%
if __name__ == "__main__":

    # ==================================================
    # INPUT – BẠN CHỈ CẦN ĐỔI PHẦN NÀY
    # ==================================================
    A = np.array([[1., 0.],
                  [0., -4.]])
    b = np.array([2., 2.])
    x0 = np.array([-1., 2.])

    lr_list = [1/7, 1/10]
    max_iter = 100

    # ==================================================
    # (a) Tìm nghiệm tối ưu
    # ==================================================
    f = create_least_squares_problem(A, b)
    grad_f = grad(f)

    # Nghiệm tối ưu (least squares)
    x_star = np.linalg.pinv(A) @ b
    p_star = f(x_star)

    print("===== (a) NGHIỆM TỐI ƯU =====")
    print("x* =", x_star)
    print("p* =", p_star)

    # ==================================================
    # (b) Gradient Descent với 2 learning rate
    # ==================================================
    histories = {}

    for lr in lr_list:
        xs, fs = gradient_descent(f, grad_f, x0, lr, max_iter)
        histories[lr] = (xs, fs)

    # ==================================================
    # Vẽ đồ thị sai số
    # ==================================================
    plt.figure(figsize=(8, 5))

    for lr in lr_list:
        _, fs = histories[lr]
        error = np.abs(fs - p_star)
        plt.semilogy(error, label=f"lr = {lr}")

    plt.xlabel("Iteration k")
    plt.ylabel(r"$|f(x^{(k)}) - p^*|$")
    plt.title("Sai số Gradient Descent")
    plt.grid(True)
    plt.legend()
    plt.show()

    # ==================================================
    # (c) Điều kiện hội tụ
    # ==================================================
    lr_max = gd_convergence_condition(A)

    print("\n===== (c) ĐIỀU KIỆN HỘI TỤ =====")
    print("Gradient Descent hội tụ nếu:")
    print("0 < learning rate < ", lr_max)

    # ==================================================
    # (d) Đổi A, b
    # ==================================================
    A2 = np.array([[1., -2.],
                   [2., -4.]])
    b2 = np.array([2., 2.])

    f2 = create_least_squares_problem(A2, b2)
    x_star_2 = np.linalg.pinv(A2) @ b2
    p_star_2 = f2(x_star_2)

    print("\n===== (d) TRƯỜNG HỢP MA TRẬN MỚI =====")
    print("x* =", x_star_2)
    print("p* =", p_star_2)
# Out:
# ===== (a) NGHIỆM TỐI ƯU =====
# x* = [ 2.  -0.5]
# p* = 0.0
#
# === Gradient Descent (lr = 0.14285714285714285) ===
# Iter   1: x = [-0.57142857 -3.71428571], f(x) = 85.959184
# Iter   2: x = [-0.20408163  3.63265306], f(x) = 139.059559
# Iter   3: x = [ 0.11078717 -5.81341108], f(x) = 227.643261
# Iter   4: x = [0.38067472 6.33152853], f(x) = 374.669364
# Iter   5: x = [ 0.6120069  -9.28339382], f(x) = 618.147319
# Iter   6: x = [ 0.81029163 10.79293492], f(x) = 1020.950735
# Iter   7: x = [  0.98024997 -15.01948775], f(x) = 1687.044141
# Iter   8: x = [ 1.12592854 18.16791282], f(x) = 2788.309753
# Iter   9: x = [  1.2507959 -24.5016022], f(x) = 4608.895918
# Iter  10: x = [ 1.35782505 30.35920283], f(x) = 7618.529387
# Iter  11: x = [  1.44956433 -40.17611792], f(x) = 12593.706156
# Iter  12: x = [ 1.528198   50.51215161], f(x) = 20818.028195
# Iter  13: x = [  1.59559828 -66.08705207], f(x) = 34413.372967
# Iter  14: x = [ 1.65336996 83.82620981], f(x) = 56887.337360
# Iter  15: x = [   1.70288854 -108.91941261], f(x) = 94038.196383
# Iter  16: x = [  1.74533303 138.89638764], f(x) = 155450.855527
# Iter  17: x = [   1.78171403 -179.72392697], f(x) = 256969.751805
# Iter  18: x = [  1.81289774 229.93076324], f(x) = 424786.710695
# Iter  19: x = [   1.83962663 -296.76812417], f(x) = 702198.424054
# Iter  20: x = [  1.86253711 380.41615965], f(x) = 1160776.974892
# Iter  21: x = [   1.88217467 -490.24934812], f(x) = 1918835.398797
# Iter  22: x = [  1.89900686 629.17773329], f(x) = 3171952.387555
# Iter  23: x = [   1.91343445 -810.08565709], f(x) = 5243431.493112
# Iter  24: x = [   1.92580096 1040.39584483], f(x) = 8667713.281091
# Iter  25: x = [    1.93640082 -1338.79465764], f(x) = 14328260.727439
# Iter  26: x = [   1.94548642 1720.16455983], f(x) = 23685492.221053
# Iter  27: x = [ 1.95327407e+00 -2.21278301e+03], f(x) = 39153568.772212
# Iter  28: x = [1.95994920e+00 2.84386386e+03], f(x) = 64723246.336736
# Iter  29: x = [ 1.96567075e+00 -3.65753925e+03], f(x) = 106991488.841624
# Iter  30: x = [1.97057493e+00 4.70140761e+03], f(x) = 176863481.553979
# Iter  31: x = [ 1.97477851e+00 -6.04580979e+03], f(x) = 292366163.384752
# Iter  32: x = [1.97838158e+00 7.77204115e+03], f(x) = 483299168.043890
# Iter  33: x = [ 1.98146992e+00 -9.99376720e+03], f(x) = 798923114.521317
# Iter  34: x = [1.98411708e+00 1.28479864e+04], f(x) = 1320668821.963652
# Iter  35: x = [ 1.98638607e+00 -1.65199825e+04], f(x) = 2183146419.980615
# Iter  36: x = [1.98833091e+00 2.12388347e+04], f(x) = 3608874694.253585
# Iter  37: x = [ 1.98999793e+00 -2.73082160e+04], f(x) = 5965690821.113004
# Iter  38: x = [1.99142679e+00 3.51094206e+04], f(x) = 9861652173.676552
# Iter  39: x = [ 1.99265154e+00 -4.51418264e+04], f(x) = 16301914817.710178
# Iter  40: x = [1.99370132e+00 5.80383483e+04], f(x) = 26948063270.092308
# Iter  41: x = [ 1.99460113e+00 -7.46218763e+04], f(x) = 44546798466.887268
# Iter  42: x = [1.99537240e+00 9.59412696e+04], f(x) = 73638585220.772797
# Iter  43: x = [ 1.99603348e+00 -1.23354204e+05], f(x) = 121729089854.746796
# Iter  44: x = [1.99660013e+00 1.58597119e+05], f(x) = 201225638331.315979
# Iter  45: x = [ 1.99708582e+00 -2.03911725e+05], f(x) = 332638300098.706055
# Iter  46: x = [1.99750214e+00 2.62171074e+05], f(x) = 549871475673.371216
# Iter  47: x = [ 1.99785897e+00 -3.37078239e+05], f(x) = 908971214888.633667
# Iter  48: x = [1.99816483e+00 4.33385164e+05], f(x) = 1502585069509.782227
# Iter  49: x = [ 1.99842700e+00 -5.57210639e+05], f(x) = 2483865114903.924316
# Iter  50: x = [1.99865171e+00 7.16412536e+05], f(x) = 4105981108310.568359
# Iter  51: x = [ 1.99884433e+00 -9.21102975e+05], f(x) = 6787438158635.834961
# Iter  52: x = [1.99900942e+00 1.18427411e+06], f(x) = 11220050833663.316406
# Iter  53: x = [ 1.99915093e+00 -1.52263929e+06], f(x) = 18547430969933.230469
# Iter  54: x = [1.99927223e+00 1.95767794e+06], f(x) = 30660038950297.781250
# Iter  55: x = [ 1.99937620e+00 -2.51701564e+06], f(x) = 50682921530084.062500
# Iter  56: x = [1.99946531e+00 3.23616182e+06], f(x) = 83781972325240.984375
# Iter  57: x = [ 1.99954170e+00 -4.16078062e+06], f(x) = 138496729762133.046875
# Iter  58: x = [1.99960717e+00 5.34957394e+06], f(x) = 228943573688423.906250
# Iter  59: x = [ 1.99966329e+00 -6.87802478e+06], f(x) = 378457744260455.812500
# Iter  60: x = [1.99971139e+00 8.84317358e+06], f(x) = 625613822144835.125000
# Iter  61: x = [ 1.99975262e+00 -1.13697957e+07], f(x) = 1034177950892482.500000
# Iter  62: x = [1.99978796e+00 1.46183077e+07], f(x) = 1709559469842674.500000
# Iter  63: x = [ 1.99981825e+00 -1.87949681e+07], f(x) = 2826006470556257.500000
# Iter  64: x = [1.99984421e+00 2.41649579e+07], f(x) = 4671561716633812.000000
# Iter  65: x = [ 1.99986647e+00 -3.10692327e+07], f(x) = 7722377531578340.000000
# Iter  66: x = [1.99988555e+00 3.99461552e+07], f(x) = 12765562858323376.000000
# Iter  67: x = [ 1.99990190e+00 -5.13593436e+07], f(x) = 21102256969881496.000000
# Iter  68: x = [1.99991591e+00 6.60334406e+07], f(x) = 34883322746130628.000000
# Iter  69: x = [ 1.99992792e+00 -8.49001391e+07], f(x) = 57664268212991456.000000
# Iter  70: x = [1.99993822e+00 1.09157320e+08], f(x) = 95322565821475664.000000
# Iter  71: x = [ 1.99994705e+00 -1.40345127e+08], f(x) = 157574037378357664.000000
# Iter  72: x = [1.99995461e+00 1.80443734e+08], f(x) = 260479531176468704.000000
# Iter  73: x = [ 1.99996109e+00 -2.31999088e+08], f(x) = 430588612761101376.000000
# Iter  74: x = [1.99996665e+00 2.98284541e+08], f(x) = 711789339462228608.000000
# Iter  75: x = [ 1.99997142e+00 -3.83508696e+08], f(x) = 1176631357070214400.000000
# Iter  76: x = [1.99997550e+00 4.93082608e+08], f(x) = 1945043671891578624.000000
# Iter  77: x = [ 1.99997900e+00 -6.33963355e+08], f(x) = 3215276273943221760.000000
# Iter  78: x = [1.9999820e+00 8.1509574e+08], f(x) = 5315048534477569024.000000
# Iter  79: x = [ 1.99998457e+00 -1.04798024e+09], f(x) = 8786100638626183168.000000
# Iter  80: x = [1.99998678e+00 1.34740316e+09], f(x) = 14523962280177975296.000000
# Iter  81: x = [ 1.99998866e+00 -1.73237550e+09], f(x) = 24008998871314608128.000000
# Iter  82: x = [1.99999028e+00 2.22733992e+09], f(x) = 39688345072989454336.000000
# Iter  83: x = [ 1.99999167e+00 -2.86372276e+09], f(x) = 65607264304329515008.000000
# Iter  84: x = [1.99999286e+00 3.68192926e+09], f(x) = 108452824666340589568.000000
# Iter  85: x = [ 1.99999388e+00 -4.73390905e+09], f(x) = 179279159142318047232.000000
# Iter  86: x = [1.99999476e+00 6.08645449e+09], f(x) = 296359426337301135360.000000
# Iter  87: x = [ 1.99999550e+00 -7.82544149e+09], f(x) = 489900276190232379392.000000
# Iter  88: x = [1.99999615e+00 1.00612819e+10], f(x) = 809835150436914167808.000000
# Iter  89: x = [ 1.99999670e+00 -1.29359339e+10], f(x) = 1338707085416123072512.000000
# Iter  90: x = [1.99999717e+00 1.66319150e+10], f(x) = 2212964773851141767168.000000
# Iter  91: x = [ 1.99999757e+00 -2.13838907e+10], f(x) = 3658166258815150850048.000000
# Iter  92: x = [1.99999792e+00 2.74935738e+10], f(x) = 6047172795184227287040.000000
# Iter  93: x = [ 1.99999822e+00 -3.53488806e+10], f(x) = 9996346865508616765440.000000
# Iter  94: x = [1.99999847e+00 4.54485607e+10], f(x) = 16524573389922408333312.000000
# Iter  95: x = [ 1.99999869e+00 -5.84338638e+10], f(x) = 27316131522116627464192.000000
# Iter  96: x = [1.99999888e+00 7.51292535e+10], f(x) = 45155237822274425847808.000000
# Iter  97: x = [ 1.99999904e+00 -9.65947545e+10], f(x) = 74644372726616875335680.000000
# Iter  98: x = [1.99999918e+00 1.24193256e+11], f(x) = 123391718180733996498944.000000
# Iter  99: x = [ 1.99999929e+00 -1.59677043e+11], f(x) = 203974064747743924977664.000000
# Iter 100: x = [1.99999939e+00 2.05299055e+11], f(x) = 337181617236066355380224.000000
#
# === Gradient Descent (lr = 0.1) ===
# Iter   1: x = [-0.7 -2. ], f(x) = 21.645000
# Iter   2: x = [-0.43  0.4 ], f(x) = 9.432450
# Iter   3: x = [-0.187 -1.04 ], f(x) = 4.724285
# Iter   4: x = [ 0.0317 -0.176 ], f(x) = 2.776910
# Iter   5: x = [ 0.22853 -0.6944 ], f(x) = 1.871384
# Iter   6: x = [ 0.405677 -0.38336 ], f(x) = 1.379772
# Iter   7: x = [ 0.5651093 -0.569984 ], f(x) = 1.068638
# Iter   8: x = [ 0.70859837 -0.4580096 ], f(x) = 0.847965
# Iter   9: x = [ 0.83773853 -0.52519424], f(x) = 0.680504
# Iter  10: x = [ 0.95396468 -0.48488346], f(x) = 0.548923
# Iter  11: x = [ 1.05856821 -0.50906993], f(x) = 0.443805
# Iter  12: x = [ 1.15271139 -0.49455804], f(x) = 0.359186
# Iter  13: x = [ 1.23744025 -0.50326517], f(x) = 0.290834
# Iter  14: x = [ 1.31369623 -0.4980409 ], f(x) = 0.235537
# Iter  15: x = [ 1.3823266  -0.50117546], f(x) = 0.190771
# Iter  16: x = [ 1.44409394 -0.49929472], f(x) = 0.154520
# Iter  17: x = [ 1.49968455 -0.50042317], f(x) = 0.125159
# Iter  18: x = [ 1.54971609 -0.4997461 ], f(x) = 0.101378
# Iter  19: x = [ 1.59474448 -0.50015234], f(x) = 0.082116
# Iter  20: x = [ 1.63527004 -0.4999086 ], f(x) = 0.066514
# Iter  21: x = [ 1.67174303 -0.50005484], f(x) = 0.053876
# Iter  22: x = [ 1.70456873 -0.49996709], f(x) = 0.043640
# Iter  23: x = [ 1.73411186 -0.50001974], f(x) = 0.035348
# Iter  24: x = [ 1.76070067 -0.49998815], f(x) = 0.028632
# Iter  25: x = [ 1.7846306  -0.50000711], f(x) = 0.023192
# Iter  26: x = [ 1.80616754 -0.49999574], f(x) = 0.018786
# Iter  27: x = [ 1.82555079 -0.50000256], f(x) = 0.015216
# Iter  28: x = [ 1.84299571 -0.49999846], f(x) = 0.012325
# Iter  29: x = [ 1.85869614 -0.50000092], f(x) = 0.009983
# Iter  30: x = [ 1.87282653 -0.49999945], f(x) = 0.008087
# Iter  31: x = [ 1.88554387 -0.50000033], f(x) = 0.006550
# Iter  32: x = [ 1.89698949 -0.4999998 ], f(x) = 0.005306
# Iter  33: x = [ 1.90729054 -0.50000012], f(x) = 0.004298
# Iter  34: x = [ 1.91656148 -0.49999993], f(x) = 0.003481
# Iter  35: x = [ 1.92490533 -0.50000004], f(x) = 0.002820
# Iter  36: x = [ 1.9324148  -0.49999997], f(x) = 0.002284
# Iter  37: x = [ 1.93917332 -0.50000002], f(x) = 0.001850
# Iter  38: x = [ 1.94525599 -0.49999999], f(x) = 0.001498
# Iter  39: x = [ 1.95073039 -0.50000001], f(x) = 0.001214
# Iter  40: x = [ 1.95565735 -0.5       ], f(x) = 0.000983
# Iter  41: x = [ 1.96009162 -0.5       ], f(x) = 0.000796
# Iter  42: x = [ 1.96408245 -0.5       ], f(x) = 0.000645
# Iter  43: x = [ 1.96767421 -0.5       ], f(x) = 0.000522
# Iter  44: x = [ 1.97090679 -0.5       ], f(x) = 0.000423
# Iter  45: x = [ 1.97381611 -0.5       ], f(x) = 0.000343
# Iter  46: x = [ 1.9764345 -0.5      ], f(x) = 0.000278
# Iter  47: x = [ 1.97879105 -0.5       ], f(x) = 0.000225
# Iter  48: x = [ 1.98091194 -0.5       ], f(x) = 0.000182
# Iter  49: x = [ 1.98282075 -0.5       ], f(x) = 0.000148
# Iter  50: x = [ 1.98453867 -0.5       ], f(x) = 0.000120
# Iter  51: x = [ 1.98608481 -0.5       ], f(x) = 0.000097
# Iter  52: x = [ 1.98747633 -0.5       ], f(x) = 0.000078
# Iter  53: x = [ 1.98872869 -0.5       ], f(x) = 0.000064
# Iter  54: x = [ 1.98985582 -0.5       ], f(x) = 0.000051
# Iter  55: x = [ 1.99087024 -0.5       ], f(x) = 0.000042
# Iter  56: x = [ 1.99178322 -0.5       ], f(x) = 0.000034
# Iter  57: x = [ 1.9926049 -0.5      ], f(x) = 0.000027
# Iter  58: x = [ 1.99334441 -0.5       ], f(x) = 0.000022
# Iter  59: x = [ 1.99400997 -0.5       ], f(x) = 0.000018
# Iter  60: x = [ 1.99460897 -0.5       ], f(x) = 0.000015
# Iter  61: x = [ 1.99514807 -0.5       ], f(x) = 0.000012
# Iter  62: x = [ 1.99563326 -0.5       ], f(x) = 0.000010
# Iter  63: x = [ 1.99606994 -0.5       ], f(x) = 0.000008
# Iter  64: x = [ 1.99646294 -0.5       ], f(x) = 0.000006
# Iter  65: x = [ 1.99681665 -0.5       ], f(x) = 0.000005
# Iter  66: x = [ 1.99713499 -0.5       ], f(x) = 0.000004
# Iter  67: x = [ 1.99742149 -0.5       ], f(x) = 0.000003
# Iter  68: x = [ 1.99767934 -0.5       ], f(x) = 0.000003
# Iter  69: x = [ 1.9979114 -0.5      ], f(x) = 0.000002
# Iter  70: x = [ 1.99812026 -0.5       ], f(x) = 0.000002
# Iter  71: x = [ 1.99830824 -0.5       ], f(x) = 0.000001
# Iter  72: x = [ 1.99847741 -0.5       ], f(x) = 0.000001
# Iter  73: x = [ 1.99862967 -0.5       ], f(x) = 0.000001
# Iter  74: x = [ 1.99876671 -0.5       ], f(x) = 0.000001
# Iter  75: x = [ 1.99889003 -0.5       ], f(x) = 0.000001
# Iter  76: x = [ 1.99900103 -0.5       ], f(x) = 0.000000
# Iter  77: x = [ 1.99910093 -0.5       ], f(x) = 0.000000
# Iter  78: x = [ 1.99919084 -0.5       ], f(x) = 0.000000
# Iter  79: x = [ 1.99927175 -0.5       ], f(x) = 0.000000
# Iter  80: x = [ 1.99934458 -0.5       ], f(x) = 0.000000
# Iter  81: x = [ 1.99941012 -0.5       ], f(x) = 0.000000
# Iter  82: x = [ 1.99946911 -0.5       ], f(x) = 0.000000
# Iter  83: x = [ 1.9995222 -0.5      ], f(x) = 0.000000
# Iter  84: x = [ 1.99956998 -0.5       ], f(x) = 0.000000
# Iter  85: x = [ 1.99961298 -0.5       ], f(x) = 0.000000
# Iter  86: x = [ 1.99965168 -0.5       ], f(x) = 0.000000
# Iter  87: x = [ 1.99968651 -0.5       ], f(x) = 0.000000
# Iter  88: x = [ 1.99971786 -0.5       ], f(x) = 0.000000
# Iter  89: x = [ 1.99974608 -0.5       ], f(x) = 0.000000
# Iter  90: x = [ 1.99977147 -0.5       ], f(x) = 0.000000
# Iter  91: x = [ 1.99979432 -0.5       ], f(x) = 0.000000
# Iter  92: x = [ 1.99981489 -0.5       ], f(x) = 0.000000
# Iter  93: x = [ 1.9998334 -0.5      ], f(x) = 0.000000
# Iter  94: x = [ 1.99985006 -0.5       ], f(x) = 0.000000
# Iter  95: x = [ 1.99986505 -0.5       ], f(x) = 0.000000
# Iter  96: x = [ 1.99987855 -0.5       ], f(x) = 0.000000
# Iter  97: x = [ 1.99989069 -0.5       ], f(x) = 0.000000
# Iter  98: x = [ 1.99990162 -0.5       ], f(x) = 0.000000
# Iter  99: x = [ 1.99991146 -0.5       ], f(x) = 0.000000
# Iter 100: x = [ 1.99992032 -0.5       ], f(x) = 0.000000
# ===== (c) ĐIỀU KIỆN HỘI TỤ =====
# Gradient Descent hội tụ nếu:
# 0 < learning rate <  0.125
#
# ===== (d) TRƯỜNG HỢP MA TRẬN MỚI =====
# x* = [ 0.24 -0.48]
# p* = 0.4

# %% [markdown]
# Câu 2. (4 điểm) Cho ma trận $A=\begin{bmatrix}1 & 0 & 0\\ 0 & 2 & 0 \\ 0 & 0 & 3 \end{bmatrix}$ và vector $b=(1/2;1; 3/2)$. Xét bài toán tối ưu sau $\begin{align}
# \min_{x=(x_1,x_2,x_3)\in\mathbb{R}^3}\;\;\; &f_0(x)=\sum_{i=1}^3x_i\log x_i\\
# \text{subject to }\;\;\; & Ax\geq b, \quad\quad\quad\quad \quad (1) \\
# & \mathbf{1}^Tx=\dfrac{3}{2}.
# \end{align}$

# %% [markdown]
# a) (1 điểm) Xác định hàm Lagrange $L(x,\lambda,v)$ cho bài toán $(1)$.
#
# b) (2 điểm) Gọi $x^*$ và $(\lambda^*, v^*)$ lần lượt là điểm tối ưu của bài toán $(1)$ và bài toán đối ngẫu của nó. Viết điều kiện Karush-Kuhn-Tucker (KKT) cho $x^*$ và $(\lambda^*, v^*)$.
#
# c) (1 điểm) Tìm một giá trị của $x^*$ và $(\lambda^*, v^*)$ thoả điều kiện KKT vừa tìm được ở câu b), từ đó đưa ra giá trị tối ưu cho bài toán $(1)$.

# %% [markdown]
# Lưu ý: sinh viên hoàn thành Câu 2 theo mẫu dưới đây.

# %% [markdown]
# a) Hàm Lagrange $L(x,\lambda,v)$

# %% [markdown]
#
# a) Hàm Lagrange $L(x,\lambda,v) = f_0(x) + \lambda^T(Ax - b) + v(\mathbf{1}^Tx - \frac{3}{2})$.

# %%
import numpy as np
import cvxpy as cp
import sympy as sp

# =========================================================
# (A) Sinh biểu thức Lagrange L(x, λ, v) dạng ký hiệu (sympy)
# =========================================================
def build_lagrangian_symbolic(A, b, s):
    """
    A: (m,n), b: (m,), s: scalar for 1^T x = s
    Return: sympy expression L(x, lambda, v)
    """
    A = np.asarray(A, dtype=float)
    b = np.asarray(b, dtype=float).reshape(-1)
    m, n = A.shape

    x = sp.Matrix(sp.symbols(f"x1:{n+1}", positive=True, real=True))  # x_i > 0 for log
    lam = sp.Matrix(sp.symbols(f"lambda1:{m+1}", nonnegative=True, real=True))  # λ >= 0
    v = sp.Symbol("v", real=True)

    A_sp = sp.Matrix(A)
    b_sp = sp.Matrix(b)

    f0 = sum(x[i] * sp.log(x[i]) for i in range(n))
    L = f0 + (lam.T * (A_sp * x - b_sp))[0] + v * ((sp.Matrix([1]*n).T * x)[0] - s)
    return x, lam, v, sp.simplify(L)

# =========================================================
# (B) In điều kiện KKT (dạng công thức + kiểm tra số)
# =========================================================
def print_kkt_conditions_symbolic(A, b, s):
    A = np.asarray(A, dtype=float)
    b = np.asarray(b, dtype=float).reshape(-1)
    m, n = A.shape

    # Khai báo biến symbolic
    x = sp.Matrix(sp.symbols(f"x1:{n+1}", positive=True, real=True))
    lam = sp.Matrix(sp.symbols(f"lambda1:{m+1}", nonnegative=True, real=True))
    v = sp.Symbol("v", real=True)

    A_sp = sp.Matrix(A)
    b_sp = sp.Matrix(b)
    ones = sp.Matrix([1]*n)

    print("\n===== (b) ĐIỀU KIỆN KKT (CỤ THỂ) =====")

    # 1. Primal feasibility
    print("\n1) Primal feasibility:")
    for i in range(m):
        expr = (A_sp.row(i) * x)[0]   # scalar
        print(f"   {sp.pretty(expr)}  ≥  {b[i]}")
    print(f"   {sp.pretty((ones.T * x)[0])} = {s}")
    for i in range(n):
        print(f"   x{i+1} > 0")

    # 2. Dual feasibility
    print("\n2) Dual feasibility:")
    for i in range(m):
        print(f"   λ{i+1} ≥ 0")

    # 3. Complementary slackness  ✅ FIX Ở ĐÂY
    print("\n3) Complementary slackness:")
    for i in range(m):
        slack = (A_sp.row(i) * x)[0] - b_sp[i, 0]   # scalar − scalar
        print(f"   λ{i+1} · ({sp.pretty(slack)}) = 0")

    # 4. Stationarity
    print("\n4) Stationarity (∂L/∂x = 0):")
    grad_f = sp.Matrix([sp.log(x[i]) + 1 for i in range(n)])
    station = grad_f + A_sp.T * lam + v * ones

    for i in range(n):
        print(f"   ∂L/∂x{i+1} = {sp.pretty(station[i])} = 0")

# =========================================================
# (C) Giải primal bằng CVXPY và lấy (x*, λ*, v*)
# =========================================================
def solve_entropy_problem(A, b, s, solver=None, verbose=False):
    """
    Minimize sum_i x_i log x_i
    s.t. Ax >= b, 1^T x = s, x >= 0

    Trả về x_star, lambda_star (dual for Ax>=b), v_star (dual for equality)
    """
    A = np.asarray(A, dtype=float)
    b = np.asarray(b, dtype=float).reshape(-1)
    m, n = A.shape

    x = cp.Variable(n, nonneg=True)

    # Objective: sum x log x is convex on x>0.
    # Use KL divergence trick: kl_div(x,1) = x*log(x) - x + 1
    # => sum x log x = sum kl_div(x,1) + sum x - n (constant shift since sum x = s)
    obj = cp.Minimize(cp.sum(cp.kl_div(x, np.ones(n))))

    cons_ineq = (A @ x >= b)
    cons_eq = (cp.sum(x) == s)
    constraints = [cons_ineq, cons_eq]

    prob = cp.Problem(obj, constraints)

    # Solve
    if solver is None:
        prob.solve(verbose=verbose)
    else:
        prob.solve(solver=solver, verbose=verbose)

    x_star = x.value
    # Dual variables:
    lambda_star = cons_ineq.dual_value   # shape (m,)
    v_star = cons_eq.dual_value          # scalar

    # Tính đúng p* = sum x log x (không dùng obj đã shift)
    eps = 1e-12
    p_star = float(np.sum(x_star * np.log(np.maximum(x_star, eps))))

    return x_star, lambda_star, float(v_star), p_star, prob.status

# =========================================================
# (D) Kiểm tra KKT bằng số cho nghiệm tìm được
# =========================================================
def check_kkt_numeric(A, b, s, x_star, lambda_star, v_star, tol=1e-7):
    A = np.asarray(A, dtype=float)
    b = np.asarray(b, dtype=float).reshape(-1)
    x_star = np.asarray(x_star, dtype=float).reshape(-1)
    lambda_star = np.asarray(lambda_star, dtype=float).reshape(-1)

    # Primal residuals
    r_ineq = A @ x_star - b
    r_eq = np.sum(x_star) - s

    # Dual feasibility
    dual_ok = np.all(lambda_star >= -tol)

    # Complementary slackness
    comp = lambda_star * r_ineq
    comp_ok = np.all(np.abs(comp) <= 1e-5)

    # Stationarity: log(x)+1 + A^T λ + v*1 = 0
    eps = 1e-12
    station = (np.log(np.maximum(x_star, eps)) + 1.0) + (A.T @ lambda_star) + v_star * np.ones_like(x_star)
    station_ok = np.all(np.abs(station) <= 1e-5)

    primal_ok = (np.all(r_ineq >= -tol) and abs(r_eq) <= 1e-5 and np.all(x_star >= -tol))

    return {
        "primal_ok": primal_ok,
        "dual_ok": dual_ok,
        "comp_ok": comp_ok,
        "station_ok": station_ok,
        "ineq_residual": r_ineq,
        "eq_residual": r_eq,
        "comp_residual": comp,
        "station_residual": station
    }

# =========================================================
# MAIN: chạy đúng bài bạn đưa
# =========================================================
if __name__ == "__main__":
    # ----- INPUT (chỉ cần đổi chỗ này cho bài khác) -----
    A = np.array([
        [1., 0., 0.],
        [0., 2., 0.],
        [0., 0., 3.]
    ])
    b = np.array([0.5, 1.0, 1.5])
    s = 1.5  # 1^T x = 3/2

    # (a) Sinh & in Lagrangian theo mẫu
    x_sym, lam_sym, v_sym, L_sym = build_lagrangian_symbolic(A, b, s)
    print("===== (a) HÀM LAGRANGE =====")
    print("L(x, λ, v) =")
    print(L_sym)

    # (b) In điều kiện KKT
    print_kkt_conditions_symbolic(A, b, s)


    # (c) Tìm một nghiệm thỏa KKT bằng cách giải primal + lấy dual
    x_star, lambda_star, v_star, p_star, status = solve_entropy_problem(A, b, s)
    print("\n===== (c) NGHIỆM THỎA KKT (từ nghiệm tối ưu primal/dual) =====")
    print("Solver status:", status)
    print("x* =", x_star)
    print("lambda* =", lambda_star)
    print("v* =", v_star)
    print("p* = sum_i x_i log x_i =", p_star)

    # Check KKT numeric
    kkt = check_kkt_numeric(A, b, s, x_star, lambda_star, v_star)
    print("\n===== KIỂM TRA KKT (NUMERIC) =====")
    print("Primal feasible:", kkt["primal_ok"])
    print("Dual feasible  :", kkt["dual_ok"])
    print("Complementary  :", kkt["comp_ok"])
    print("Stationarity   :", kkt["station_ok"])
    print("Ineq residual Ax-b:", kkt["ineq_residual"])
    print("Eq residual 1^T x - s:", kkt["eq_residual"])
# Out:
# ===== (a) HÀM LAGRANGE =====
# L(x, λ, v) =
# lambda1*(1.0*x1 - 0.5) + lambda2*(2.0*x2 - 1.0) + lambda3*(3.0*x3 - 1.5) + v*(x1 + x2 + x3 - 1.5) + log(x1**x1*x2**x2*x3**x3)
#
# ===== (b) ĐIỀU KIỆN KKT (CỤ THỂ) =====
#
# 1) Primal feasibility:
#    1.0⋅x₁  ≥  0.5
#    2.0⋅x₂  ≥  1.0
#    3.0⋅x₃  ≥  1.5
#    x₁ + x₂ + x₃ = 1.5
#    x1 > 0
#    x2 > 0
#    x3 > 0
#
# 2) Dual feasibility:
#    λ1 ≥ 0
#    λ2 ≥ 0
#    λ3 ≥ 0
#
# 3) Complementary slackness:
#    λ1 · (1.0⋅x₁ - 0.5) = 0
#    λ2 · (2.0⋅x₂ - 1.0) = 0
#    λ3 · (3.0⋅x₃ - 1.5) = 0
#
# 4) Stationarity (∂L/∂x = 0):
#    ∂L/∂x1 = 1.0⋅λ₁ + v + log(x₁) + 1 = 0
#    ∂L/∂x2 = 2.0⋅λ₂ + v + log(x₂) + 1 = 0
#    ∂L/∂x3 = 3.0⋅λ₃ + v + log(x₃) + 1 = 0
#
# ===== (c) NGHIỆM THỎA KKT (từ nghiệm tối ưu primal/dual) =====
# Solver status: optimal
# x* = [0.5 0.5 0.5]
# lambda* = [1.13949839 0.56974895 0.379832  ]
# v* = 1.8325921979328539
# p* = sum_i x_i log x_i = -1.0397207726059126
#
# ===== KIỂM TRA KKT (NUMERIC) =====
# Primal feasible: True
# Dual feasible  : True
# Complementary  : True
# Stationarity   : False
# Ineq residual Ax-b: [-3.26164640e-09 -3.22760330e-09 -2.63920996e-09]
# Eq residual 1^T x - s: -5.755184773192923e-09

# %%
# ============================================================
# KIẾN TRÚC CHUẨN KKT (TỔNG QUÁT n-CHIỀU)
#   - Chuẩn hóa ràng buộc về dạng:
#       g(x) <= 0
#       h(x) = 0
#   - Sinh Lagrangian L = f + λ^T g + v h
#   - Sinh KKT (primal/dual feasibility, complementary slackness, stationarity)
#   - Giải primal/dual bằng CVXPY và kiểm tra KKT bằng số
# ============================================================

import numpy as np
import cvxpy as cp
import sympy as sp
from dataclasses import dataclass

# -----------------------------
# 1) Đặc tả bài toán (linh hoạt)
# -----------------------------
@dataclass
class KKTProblemSpec:
    A: np.ndarray          # (m,n)
    b: np.ndarray          # (m,)
    c: np.ndarray          # (n,)  (vector trong đẳng thức c^T x = s)
    s: float               # scalar
    ineq_type: str = ">="  # ">=" hoặc "<=" ; nghĩa là Ax >= b hoặc Ax <= b

    def __post_init__(self):
        self.A = np.asarray(self.A, dtype=float)
        self.b = np.asarray(self.b, dtype=float).reshape(-1)
        self.c = np.asarray(self.c, dtype=float).reshape(-1)
        m, n = self.A.shape
        assert self.b.shape == (m,), "b phải có shape (m,)"
        assert self.c.shape == (n,), "c phải có shape (n,)"
        assert self.ineq_type in (">=", "<="), "ineq_type chỉ nhận '>=' hoặc '<='"

    # ----------------------------------------
    # 2) Chuẩn hóa ràng buộc về g(x) <= 0, h(x)=0
    # ----------------------------------------
    def g_linear(self, x):
        """g(x) <= 0 (numpy)"""
        if self.ineq_type == ">=":
            # Ax >= b  <=>  b - Ax <= 0
            return self.b - self.A @ x
        else:
            # Ax <= b  <=>  Ax - b <= 0
            return self.A @ x - self.b

    def h_linear(self, x):
        """h(x)=0 (numpy)"""
        return float(self.c @ x - self.s)

    def Jg(self):
        """Jacobian của g theo x: g(x)=M x + q => Jg = M"""
        if self.ineq_type == ">=":
            # g = b - A x => Jg = -A
            return -self.A
        else:
            # g = A x - b => Jg = A
            return self.A

    def Jh(self):
        """Jacobian của h theo x: h = c^T x - s => Jh = c^T"""
        return self.c.reshape(1, -1)

# -----------------------------------------
# 3) Objective entropy: f(x)=sum x_i log x_i
# -----------------------------------------
def f_entropy_np(x, eps=1e-12):
    x = np.asarray(x, dtype=float)
    return float(np.sum(x * np.log(np.maximum(x, eps))))

def build_symbolic_objects(spec: KKTProblemSpec):
    """Sinh x, λ, v và biểu thức L(x,λ,v) theo SymPy (tổng quát)."""
    m, n = spec.A.shape

    x = sp.Matrix(sp.symbols(f"x1:{n+1}", positive=True, real=True))  # x_i > 0
    lam = sp.Matrix(sp.symbols(f"lambda1:{m+1}", nonnegative=True, real=True))  # λ >= 0
    v = sp.Symbol("v", real=True)

    A_sp = sp.Matrix(spec.A)
    b_sp = sp.Matrix(spec.b)
    c_sp = sp.Matrix(spec.c)

    # f(x) = Σ x log x
    f0 = sum(x[i] * sp.log(x[i]) for i in range(n))

    # g(x) <= 0
    if spec.ineq_type == ">=":
        # g = b - A x
        g = b_sp - A_sp * x
    else:
        # g = A x - b
        g = A_sp * x - b_sp

    # h(x)=0: c^T x - s
    h = (c_sp.T * x)[0] - spec.s

    # L = f + λ^T g + v h
    L = f0 + (lam.T * g)[0] + v * h
    return x, lam, v, sp.simplify(L), g, h

# -----------------------------------------
# 4) In bài làm: Lagrangian + KKT "cụ thể"
# -----------------------------------------
def print_lagrangian_and_kkt(spec: KKTProblemSpec):
    x, lam, v, L, g_sym, h_sym = build_symbolic_objects(spec)
    m, n = spec.A.shape

    print("===== (a) HÀM LAGRANGE =====")
    print("L(x, λ, v) =")
    print(L)

    print("\n===== (b) ĐIỀU KIỆN KKT (CỤ THỂ – TỰ ĐỘNG THEO INPUT) =====")

    # 1) Primal feasibility
    print("\n1) Primal feasibility:")
    # In ra ràng buộc g(x) <= 0 tương ứng với Ax >= b / Ax <= b
    for i in range(m):
        if spec.ineq_type == ">=":
            # Ax >= b
            lhs = (sp.Matrix(spec.A).row(i) * sp.Matrix(x))[0]
            print(f"   {sp.pretty(lhs)}  ≥  {spec.b[i]}")
        else:
            lhs = (sp.Matrix(spec.A).row(i) * sp.Matrix(x))[0]
            print(f"   {sp.pretty(lhs)}  ≤  {spec.b[i]}")
    # Equality
    c_sp = sp.Matrix(spec.c)
    print(f"   {sp.pretty((c_sp.T * x)[0])}  =  {spec.s}")
    # Domain
    for i in range(n):
        print(f"   x{i+1} > 0")

    # 2) Dual feasibility
    print("\n2) Dual feasibility:")
    for i in range(m):
        print(f"   λ{i+1} ≥ 0")

    # 3) Complementary slackness: λ_i * g_i(x)=0
    print("\n3) Complementary slackness:")
    for i in range(m):
        print(f"   λ{i+1} · ({sp.pretty(g_sym[i])}) = 0")

    # 4) Stationarity: ∇f + Jg^T λ + Jh^T v = 0
    print("\n4) Stationarity (∂L/∂x = 0):")
    grad_f = sp.Matrix([sp.log(x[i]) + 1 for i in range(n)])
    Jg_sp = sp.Matrix(spec.Jg())          # (m,n)
    Jh_sp = sp.Matrix(spec.Jh())          # (1,n)
    station = grad_f + Jg_sp.T * lam + Jh_sp.T * v
    for i in range(n):
        print(f"   ∂L/∂x{i+1} = {sp.pretty(sp.simplify(station[i]))} = 0")

# -----------------------------------------
# 5) Giải primal/dual bằng CVXPY (tổng quát)
# -----------------------------------------
def solve_primal_dual(spec: KKTProblemSpec, solver=None, verbose=False):
    """
    Giải:
        min Σ x_i log x_i
        s.t. Ax (>= or <=) b
             c^T x = s
             x >= 0
    Lấy dual λ* cho bất đẳng thức (tương ứng g(x)<=0 chuẩn hóa) và v* cho đẳng thức.
    """
    A, b, c, s = spec.A, spec.b, spec.c, spec.s
    m, n = A.shape

    x = cp.Variable(n, nonneg=True)

    # Dùng kl_div: kl_div(x,1) = x log x - x + 1 (convex)
    # Vì c^T x = s cố định, nên tối ưu tương đương
    obj = cp.Minimize(cp.sum(cp.kl_div(x, np.ones(n))))

    if spec.ineq_type == ">=":
        cons_ineq = (A @ x >= b)
    else:
        cons_ineq = (A @ x <= b)

    cons_eq = (c @ x == s)

    prob = cp.Problem(obj, [cons_ineq, cons_eq])

    if solver is None:
        prob.solve(verbose=verbose)
    else:
        prob.solve(solver=solver, verbose=verbose)

    x_star = np.asarray(x.value, dtype=float).reshape(-1)

    # CVXPY dual_value trả về dual đúng theo canonical g(x)<=0:
    # - Nếu viết A x >= b => canonical là b - A x <= 0 => dual >=0 chính là λ cho g=b-Ax
    # - Nếu viết A x <= b => canonical là A x - b <= 0 => dual >=0 chính là λ cho g=Ax-b
    lambda_star = np.asarray(cons_ineq.dual_value, dtype=float).reshape(-1)
    v_star = float(cons_eq.dual_value)

    p_star = f_entropy_np(x_star)

    return {
        "status": prob.status,
        "x_star": x_star,
        "lambda_star": lambda_star,
        "v_star": v_star,
        "p_star": p_star
    }

# -----------------------------------------
# 6) Kiểm tra KKT bằng số (tổng quát)
# -----------------------------------------
def check_kkt_numeric(spec: KKTProblemSpec, x_star, lambda_star, v_star, tol=1e-6):
    A, b, c, s = spec.A, spec.b, spec.c, spec.s
    x_star = np.asarray(x_star, dtype=float).reshape(-1)
    lambda_star = np.asarray(lambda_star, dtype=float).reshape(-1)

    # g(x) <= 0
    g = spec.g_linear(x_star)
    # h(x) = 0
    h = spec.h_linear(x_star)

    primal_ok = (np.all(g <= tol) and abs(h) <= 1e-5 and np.all(x_star >= -tol))
    dual_ok = np.all(lambda_star >= -tol)

    comp = lambda_star * g
    comp_ok = np.all(np.abs(comp) <= 1e-5)

    # stationarity: ∇f + Jg^T λ + Jh^T v = 0
    eps = 1e-12
    grad_f = np.log(np.maximum(x_star, eps)) + 1.0               # (n,)
    station = grad_f + spec.Jg().T @ lambda_star + spec.Jh().T.flatten() * v_star
    station_ok = np.all(np.abs(station) <= 1e-5)

    return {
        "primal_ok": primal_ok,
        "dual_ok": dual_ok,
        "comp_ok": comp_ok,
        "station_ok": station_ok,
        "g(x*)": g,
        "h(x*)": h,
        "comp_residual": comp,
        "station_residual": station
    }

# ============================================================
# MAIN DEMO: ĐÚNG BÀI BẠN ĐƯA (có thể đổi input tùy ý)
# ============================================================
if __name__ == "__main__":
    # ---------- INPUT ----------
    A = np.array([[1., 0., 0.],
                  [0., 2., 0.],
                  [0., 0., 3.]])
    b = np.array([0.5, 1.0, 1.5])
    c = np.ones(3)      # đổi thành vector khác nếu muốn: np.array([1,2,1]) ...
    s = 1.5
    ineq_type = ">="    # đổi thành "<=" nếu Ax <= b

    spec = KKTProblemSpec(A=A, b=b, c=c, s=s, ineq_type=ineq_type)

    # (a) + (b): In Lagrangian và KKT cụ thể (tự động theo subject to)
    print_lagrangian_and_kkt(spec)

    # (c): Giải primal/dual, lấy x*, (λ*, v*), p*
    sol = solve_primal_dual(spec, solver=None, verbose=False)
    print("\n===== (c) NGHIỆM THỎA KKT (từ nghiệm tối ưu primal/dual) =====")
    print("Status:", sol["status"])
    print("x* =", sol["x_star"])
    print("lambda* =", sol["lambda_star"])
    print("v* =", sol["v_star"])
    print("p* = Σ x_i log x_i =", sol["p_star"])

    # Kiểm tra KKT số
    kkt = check_kkt_numeric(spec, sol["x_star"], sol["lambda_star"], sol["v_star"])
    print("\n===== KIỂM TRA KKT (NUMERIC) =====")
    print("Primal feasible:", kkt["primal_ok"])
    print("Dual feasible  :", kkt["dual_ok"])
    print("Complementary  :", kkt["comp_ok"])
    print("Stationarity   :", kkt["station_ok"])
    print("g(x*) =", kkt["g(x*)"])
    print("h(x*) =", kkt["h(x*)"])
# Out:
# ===== (a) HÀM LAGRANGE =====
# L(x, λ, v) =
# -lambda1*(1.0*x1 - 0.5) - lambda2*(2.0*x2 - 1.0) - lambda3*(3.0*x3 - 1.5) + v*(1.0*x1 + 1.0*x2 + 1.0*x3 - 1.5) + log(x1**x1*x2**x2*x3**x3)
#
# ===== (b) ĐIỀU KIỆN KKT (CỤ THỂ – TỰ ĐỘNG THEO INPUT) =====
#
# 1) Primal feasibility:
#    1.0⋅x₁  ≥  0.5
#    2.0⋅x₂  ≥  1.0
#    3.0⋅x₃  ≥  1.5
#    1.0⋅x₁ + 1.0⋅x₂ + 1.0⋅x₃  =  1.5
#    x1 > 0
#    x2 > 0
#    x3 > 0
#
# 2) Dual feasibility:
#    λ1 ≥ 0
#    λ2 ≥ 0
#    λ3 ≥ 0
#
# 3) Complementary slackness:
#    λ1 · (0.5 - 1.0⋅x₁) = 0
#    λ2 · (1.0 - 2.0⋅x₂) = 0
#    λ3 · (1.5 - 3.0⋅x₃) = 0
#
# 4) Stationarity (∂L/∂x = 0):
#    ∂L/∂x1 = -1.0⋅λ₁ + 1.0⋅v + 1.0⋅log(x₁) + 1.0 = 0
#    ∂L/∂x2 = -2.0⋅λ₂ + 1.0⋅v + log(x₂) + 1 = 0
#    ∂L/∂x3 = -3.0⋅λ₃ + 1.0⋅v + log(x₃) + 1 = 0
#
# ===== (c) NGHIỆM THỎA KKT (từ nghiệm tối ưu primal/dual) =====
# Status: optimal
# x* = [0.5 0.5 0.5]
# lambda* = [1.13949839 0.56974895 0.379832  ]
# v* = 1.8325921979328539
# p* = Σ x_i log x_i = -1.0397207726059126
#
# ===== KIỂM TRA KKT (NUMERIC) =====
# Primal feasible: True
# Dual feasible  : True
# Complementary  : True
# Stationarity   : False
# g(x*) = [3.26164640e-09 3.22760330e-09 2.63920996e-09]
# h(x*) = -5.755184773192923e-09

# %% [markdown]
# ## --------------------------------------- Hết --------------------------------------

# %% [markdown]
# ### Lưu ý: sinh viên không được sử dụng internet. Giám thị không giải thích gì thêm.
