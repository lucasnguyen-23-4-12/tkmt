# %% [markdown]
# ### Câu 1 (3 điểm)

# %% [markdown]
# Một cơ sở sản xuất đồ gỗ dự định sản xuất ba loại sản phẩm là bàn,
# ghế và tủ. Định mức sử dụng lao động, chi phí sản xuất và giá bán mỗi sản phẩm mỗi loại ước tính trong bảng sau:
#
# | Các yếu tố   |  Bàn |  Ghế | Tủ |
# |---|---|---|---|
# | Lao động (ngày công)   |  2 | 1  | 3  |
# | Chi phí sản xuất (ngàn đồng)   | 100 | 40  | 250  |
# | Giá bán (ngàn đồng)   | 260  | 120  |  600 |
#
# Bài toán đặt ra là xác định số sản phẩm mỗi loại cần phải sản xuất sao cho không bị động trong sản xuất và tổng doanh thu đạt được cao nhất, biết rằng cơ sở có số lao động tương đương với 500 ngày công, số tiền dành cho chi phí sản xuất là 40 triệu đồng và số bàn, ghế phải theo tỉ lệ 1/6.
#
# 1.  Hãy lập mô hình tối ưu của bài toán trên theo dạng dưới đây bằng cách chỉ ra $f_0, A, b$ và $h$.
# \begin{align}
# \text{minimize}\quad & f_0(x),\\
# \text{subject to}\quad & Ax\leq b,\\
# & h(x)=0.
# \end{align}
#
#
# 2.  Sử dụng `scipy.optimize.linprog` để giải bài toán trên.
#
#
# 3.  Sử dụng `cvxpy` để giải bài toán trên.
#
# *Lưu ý: Chấp nhận số lượng bàn ghế là số thực.*

# %% [markdown]
# đặt x1 là bàn, x2 là ghế, x3 là tủ</br>
# Lấy giá bán trừ đi tri phí sản xuất, ta được số tiền lời</br>
# ==>để đạt lợi nhuận cao nhất, ta tìm max 160x1 + 80x2 + 360x3</br>
# > f0 = max 160x1 + 80x2 + 360x3</br>
# > sb to : 2x1 + 1x2 + 3x3 <= 500</br>
# >         100x1 + 40x2 + 250x3 <= 40000</br>
# > h(x) :     6x1 - x2 = 0 </br>
#  >x1,x2,x3 > 0

# %%
import numpy as np
from scipy.optimize import linprog

# %% [markdown]
# ### Cau 1.2

# %%
import numpy as np
from scipy.optimize import linprog

# Các hệ số của hàm mục tiêu (doanh thu), cần tối thiểu hóa nên ta nhân với -1
c = np.array([-260, -120, -600])

# Ràng buộc bất đẳng thức Ax <= b
A_ub = np.array([
    [2, 1, 3],          # Lao động
    [100, 40, 250]      # Chi phí sản xuất
])
b_ub = np.array([500, 40000])

# Ràng buộc đẳng thức A_eq*x = b_eq
A_eq = np.array([
    [6, -1, 0]          # Tỷ lệ bàn/ghế
])
b_eq = np.array([0])

# Ràng buộc về biến: số lượng sản phẩm không âm
bounds = [(0, None), (0, None), (0, None)]

# Giải bài toán
result = linprog(c, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=bounds)

if result.success:
    x_opt = result.x
    total_revenue = -result.fun
    print(f"Số lượng sản phẩm tối ưu:")
    print(f"  Bàn (x1): {x_opt[0]:.2f}")
    print(f"  Ghế (x2): {x_opt[1]:.2f}")
    print(f"  Tủ (x3): {x_opt[2]:.2f}")
    print(f"Doanh thu tối đa: {total_revenue:.2f} ngàn đồng")
else:
    print("Bài toán không tìm thấy lời giải tối ưu.")
    print(result.message)
# Out:
# Số lượng sản phẩm tối ưu:
#   Bàn (x1): 5.10
#   Ghế (x2): 30.61
#   Tủ (x3): 153.06
# Doanh thu tối đa: 96836.73 ngàn đồng

# %%
pip install cvxpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Cau 1.3

# %%
import cvxpy as cp
import numpy as np

# Khai báo các biến
x = cp.Variable(3, nonneg=True)

# Hàm mục tiêu (tối đa hóa doanh thu)
objective = cp.Maximize(260*x[0] + 120*x[1] + 600*x[2])

# Các ràng buộc
constraints = [
    2*x[0] + 1*x[1] + 3*x[2] <= 500,       # Lao động
    100*x[0] + 40*x[1] + 250*x[2] <= 40000, # Chi phí
    6*x[0] - x[1] == 0                    # Tỷ lệ
]

# Tạo và giải bài toán
problem = cp.Problem(objective, constraints)
problem.solve()

# In kết quả
if problem.status == cp.OPTIMAL:
    print(f"Số lượng sản phẩm tối ưu:")
    print(f"  Bàn (x1): {x.value[0]:.2f}")
    print(f"  Ghế (x2): {x.value[1]:.2f}")
    print(f"  Tủ (x3): {x.value[2]:.2f}")
    print(f"Doanh thu tối đa: {problem.value:.2f} ngàn đồng")
else:
    print("Bài toán không tìm thấy lời giải tối ưu.")
    print(problem.status)
# Out:
# Số lượng sản phẩm tối ưu:
#   Bàn (x1): 5.10
#   Ghế (x2): 30.61
#   Tủ (x3): 153.06
# Doanh thu tối đa: 96836.73 ngàn đồng

# %%
pip install pulp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#1.4
import pulp as p

# 1. Khởi tạo bài toán
# LpMinimize để giải bài toán tối thiểu hóa
# LpMaximize để giải bài toán tối đa hóa
# Ở đây ta tối đa hóa doanh thu nên ta dùng LpMaximize
problem = p.LpProblem("Production_Optimization", p.LpMaximize)

# 2. Khai báo các biến quyết định
# cat='Continuous' để chấp nhận số thực, non-negative=True để đảm bảo >= 0
x1 = p.LpVariable("ban", lowBound=0, cat='Continuous')
x2 = p.LpVariable("ghe", lowBound=0, cat='Continuous')
x3 = p.LpVariable("tu", lowBound=0, cat='Continuous')

# 3. Thêm hàm mục tiêu vào bài toán
# Doanh thu = 260*x1 + 120*x2 + 600*x3
problem += 260 * x1 + 120 * x2 + 600 * x3, "Doanh thu"

# 4. Thêm các ràng buộc
# Ràng buộc về lao động (<= 500 ngày công)
problem += 2 * x1 + x2 + 3 * x3 <= 500, "Lao dong"

# Ràng buộc về chi phí sản xuất (<= 40 triệu đồng = 40000 ngàn đồng)
problem += 100 * x1 + 40 * x2 + 250 * x3 <= 40000, "Chi phi san xuat"

# Ràng buộc về tỷ lệ (bàn/ghế = 1/6)
problem += 6 * x1 == x2, "Ty le ban_ghe"

# 5. Giải bài toán
problem.solve()

# 6. In kết quả
print(f"Trạng thái giải quyết: {p.LpStatus[problem.status]}")
print("Số lượng sản phẩm tối ưu:")
print(f"  Bàn (x1): {x1.value():.2f}")
print(f"  Ghế (x2): {x2.value():.2f}")
print(f"  Tủ (x3): {x3.value():.2f}")
print(f"Doanh thu tối đa: {p.value(problem.objective):.2f} ngàn đồng")
# Out:
# Trạng thái giải quyết: Optimal
# Số lượng sản phẩm tối ưu:
#   Bàn (x1): 5.10
#   Ghế (x2): 30.61
#   Tủ (x3): 153.06
# Doanh thu tối đa: 96836.73 ngàn đồng

# %% [markdown]
# >> kết luận, cả 2 câu 1.2 và 1.3 đều đưa ra kết quả là 5 bàn 30 ghế và 153 tủ

# %% [markdown]
# ### Câu 2 (4 điểm)

# %% [markdown]
# 1. Cho một hàm số mục tiêu $f(x)=x^2+\sin \left(\dfrac{x}{2}\right)+2023x.$
# Hãy tính đạo hàm của hàm số này.
#
#
# 2. Sử dụng thuật toán Gradient Descent, hãy tìm giá trị của $x$ để tối ưu hóa hàm số $f(x)=x^2+\sin \left(\dfrac{x}{2}\right)+2023x,$ với giá trị $x$ ban đầu là $x^{(0)}=2024$, sử dụng learning rate là $0.9$ và thực hiện tối đa $100$ vòng lặp. In ra giá trị của $x$ và $f(x)$ tương ứng sau mỗi vòng lặp.
#
#
# 3. Bằng cách thay đổi giá trị learning rate trong thuật toán trên, hãy giải thích sự quan trọng của việc điều chỉnh tham số learning rate trong thuật toán Gradient Descent và cách lựa chọn giá trị tối ưu của nó.
#
#
# 4. Hãy trình bày một ví dụ cụ thể về một vấn đề thực tế trong học máy hoặc khoa học dữ liệu mà Gradient Descent có thể được sử dụng để giải quyết.
#
# Code mẫu (câu 2.1, 2.2):

# %%
from scipy.linalg import eigvals
import sympy as sp
# --- 1️⃣ Khai báo biến và hàm ---
x = sp.Symbol('x', real=True)
f = x**2 + sp.sin(x/2) + 2023*x

# --- 2️⃣ Tính đạo hàm và Hessian ---
grad_f = sp.diff(f, x)
hessian_f = sp.diff(grad_f, x)

print("Hàm f(x) =", f)
print("Đạo hàm f'(x) =", grad_f)
print("Hessian f''(x) =", hessian_f)

# --- 3️⃣ Chuyển sang hàm số để tính toán ---
f_func = sp.lambdify(x, f, 'numpy')
hessian_func = sp.lambdify(x, hessian_f, 'numpy')

# --- 4️⃣ Kiểm tra Hessian trên nhiều điểm ---
x_vals = np.linspace(-50, 50, 200)
H_vals = hessian_func(x_vals)

# --- 5️⃣ Kiểm tra tính xác định dương ---
min_H = np.min(H_vals)
max_H = np.max(H_vals)

print("\n--- KIỂM TRA BẰNG HESSIAN ---")
print(f"Giá trị nhỏ nhất của Hessian f''(x): {min_H:.4f}")
print(f"Giá trị lớn nhất của Hessian f''(x): {max_H:.4f}")

if np.all(H_vals > 0):
    print("✅ Hessian luôn dương → Hàm lồi nghiêm ngặt (strictly convex).")
elif np.all(H_vals >= 0):
    print("✅ Hessian không âm → Hàm lồi (convex).")
else:
    print("❌ Hessian đổi dấu → Hàm KHÔNG lồi.")
# Out:
# Hàm f(x) = x**2 + 2023*x + sin(x/2)
# Đạo hàm f'(x) = 2*x + cos(x/2)/2 + 2023
# Hessian f''(x) = 2 - sin(x/2)/4
#
# --- KIỂM TRA BẰNG HESSIAN ---
# Giá trị nhỏ nhất của Hessian f''(x): 1.7504
# Giá trị lớn nhất của Hessian f''(x): 2.2496
# ✅ Hessian luôn dương → Hàm lồi nghiêm ngặt (strictly convex).

# %%
# ============================================================
# 🧮 HÀM 2 CHIỀU: f(x1, x2) = x1^2 + 3x2^2 + 2x1x2 + sin((x1+x2)/2)
# ============================================================
import sympy as sp
import numpy as np
from scipy.linalg import eigvals

# --- 1️⃣ Khai báo biến và hàm ---
x1, x2 = sp.symbols('x1 x2', real=True)
f2 = x1**2 + 3*x2**2 + 2*x1*x2 + sp.sin((x1 + x2)/2)

# --- 2️⃣ Gradient và Hessian ---
grad_f2 = [sp.diff(f2, var) for var in (x1, x2)]
H_f2 = sp.hessian(f2, (x1, x2))

print("Hàm f(x1, x2) =", f2)
print("Gradient =", grad_f2)
print("Hessian =")
sp.pprint(H_f2)

# --- 3️⃣ Hàm tính giá trị Hessian số ---
H_func_2d = sp.lambdify((x1, x2), H_f2, 'numpy')

# --- 4️⃣ Kiểm tra Hessian tại nhiều điểm ---
test_points = [(0,0), (1,1), (-2,3), (5,-1)]
print("\n--- KIỂM TRA HESSIAN 2D ---")
for pt in test_points:
    H_val = np.array(H_func_2d(*pt), dtype=float)
    eigs = np.real(eigvals(H_val))
    print(f"Điểm {pt}: eigenvalues = {eigs}")
    if np.all(eigs > 0):
        print("→ ✅ Hessian xác định dương → Hàm lồi nghiêm ngặt tại điểm này\n")
    elif np.all(eigs >= 0):
        print("→ ✅ Hessian bán xác định dương → Hàm lồi tại điểm này\n")
    else:
        print("→ ❌ Hessian có giá trị riêng âm → KHÔNG lồi tại điểm này\n")
# Out:
# Hàm f(x1, x2) = x1**2 + 2*x1*x2 + 3*x2**2 + sin(x1/2 + x2/2)
# Gradient = [2*x1 + 2*x2 + cos(x1/2 + x2/2)/2, 2*x1 + 6*x2 + cos(x1/2 + x2/2)/2]
# Hessian =
# ⎡       ⎛x₁   x₂⎞         ⎛x₁   x₂⎞⎤
# ⎢    sin⎜── + ──⎟      sin⎜── + ──⎟⎥
# ⎢       ⎝2    2 ⎠         ⎝2    2 ⎠⎥
# ⎢2 - ────────────  2 - ────────────⎥
# ⎢         4                 4      ⎥
# ⎢                                  ⎥
# ⎢       ⎛x₁   x₂⎞         ⎛x₁   x₂⎞⎥
# ⎢    sin⎜── + ──⎟      sin⎜── + ──⎟⎥
# ⎢       ⎝2    2 ⎠         ⎝2    2 ⎠⎥
# ⎢2 - ────────────  6 - ────────────⎥
# ⎣         4                 4      ⎦
#
# --- KIỂM TRA HESSIAN 2D ---
# Điểm (0, 0): eigenvalues = [1.17157288 6.82842712]
# → ✅ Hessian xác định dương → Hàm lồi nghiêm ngặt tại điểm này
#
# Điểm (1, 1): eigenvalues = [1.10583204 6.47343247]
# → ✅ Hessian xác định dương → Hàm lồi nghiêm ngặt tại điểm này
#
# Điểm (-2, 3): eigenvalues = [1.1351591  6.62512814]
# → ✅ Hessian xác định dương → Hàm lồi nghiêm ngặt tại điểm này
#
# ...

# %%
# ============================================================
# 🧮 HÀM 3 CHIỀU: f(x1, x2, x3) = x1^2 + x2^2 + x3^2 + x1x2 + 2x2x3 + sin((x1+x2+x3)/3)
# ============================================================
x1, x2, x3 = sp.symbols('x1 x2 x3', real=True)
f3 = x1**2 + x2**2 + x3**2 + x1*x2 + 2*x2*x3 + sp.sin((x1 + x2 + x3)/3)

# --- Gradient & Hessian ---
grad_f3 = [sp.diff(f3, v) for v in (x1, x2, x3)]
H_f3 = sp.hessian(f3, (x1, x2, x3))

print("Hàm f(x1, x2, x3) =", f3)
print("Gradient =", grad_f3)
print("Hessian =")
sp.pprint(H_f3)

# --- Hàm tính Hessian ---
H_func_3d = sp.lambdify((x1, x2, x3), H_f3, 'numpy')

# --- Kiểm tra Hessian tại nhiều điểm ---
test_points_3d = [(0,0,0), (1,1,1), (-2,1,3), (3,-1,0)]
print("\n--- KIỂM TRA HESSIAN 3D ---")
for pt in test_points_3d:
    H_val = np.array(H_func_3d(*pt), dtype=float)
    eigs = np.real(eigvals(H_val))
    print(f"Điểm {pt}: eigenvalues = {np.round(eigs, 4)}")
    if np.all(eigs > 0):
        print("→ ✅ Hessian xác định dương → Hàm lồi nghiêm ngặt tại điểm này\n")
    elif np.all(eigs >= 0):
        print("→ ✅ Hessian bán xác định dương → Hàm lồi tại điểm này\n")
    else:
        print("→ ❌ Hessian có giá trị riêng âm → KHÔNG lồi tại điểm này\n")
# Out:
# Hàm f(x1, x2, x3) = x1**2 + x1*x2 + x2**2 + 2*x2*x3 + x3**2 + sin(x1/3 + x2/3 + x3/3)
# Gradient = [2*x1 + x2 + cos(x1/3 + x2/3 + x3/3)/3, x1 + 2*x2 + 2*x3 + cos(x1/3 + x2/3 + x3/3)/3, 2*x2 + 2*x3 + cos(x1/3 + x2/3 + x3/3)/3]
# Hessian =
# ⎡       ⎛x₁   x₂   x₃⎞         ⎛x₁   x₂   x₃⎞       ⎛x₁   x₂   x₃⎞  ⎤
# ⎢    sin⎜── + ── + ──⎟      sin⎜── + ── + ──⎟   -sin⎜── + ── + ──⎟  ⎥
# ⎢       ⎝3    3    3 ⎠         ⎝3    3    3 ⎠       ⎝3    3    3 ⎠  ⎥
# ⎢2 - ─────────────────  1 - ─────────────────   ─────────────────── ⎥
# ⎢            9                      9                    9          ⎥
# ⎢                                                                   ⎥
# ⎢       ⎛x₁   x₂   x₃⎞         ⎛x₁   x₂   x₃⎞         ⎛x₁   x₂   x₃⎞⎥
# ⎢    sin⎜── + ── + ──⎟      sin⎜── + ── + ──⎟      sin⎜── + ── + ──⎟⎥
# ⎢       ⎝3    3    3 ⎠         ⎝3    3    3 ⎠         ⎝3    3    3 ⎠⎥
# ⎢1 - ─────────────────  2 - ─────────────────  2 - ─────────────────⎥
# ...

# %% [markdown]
# 2.1 đạo hàm của x*x là 2x, đạo hàm của sin(x/2) =1/2*cos(x/2) ,đạo hàm của 2023x là 2023</br>
# vậy đạo hàm của f(x) là 2x + 1/2 cos(x/2) + 2023

# %%
import numpy as np
import math
# Hàm số mục tiêu
def objective_function(x):
    of = x*x + math.sin(x/2) + 2023*x
    return of

# Đạo hàm của hàm số mục tiêu
def gradient(x):

    g = 2*x + 1/2*math.cos(x/2) + 2023
    return g

def gradient_descent(learning_rate, max_iterations, initial_x):
    x = initial_x
    for i in range(max_iterations):
        x = x - learning_rate * gradient(x)
    return x
    

learning_rate = 0.9
max_iterations = 100
initial_x = 2024

final_x = gradient_descent(learning_rate, max_iterations, initial_x)
print("Giá trị x cuối cùng sau Gradient Descent:", final_x)
print("Giá trị f(x) tương ứng:", objective_function(final_x))
# Out:
# Giá trị x cuối cùng sau Gradient Descent: -1011.2535754200651
# Giá trị f(x) tương ứng: -1023132.3580921224

# %%
#2.2 thay đổi learning rate
learning_rate = np.arange(0,1,0.01)
fX =[]
Gx = []
for t in learning_rate:
    final_x = gradient_descent(t, max_iterations, initial_x)
    fX.append(final_x)
    Gx.append(objective_function(final_x))

# %%
import matplotlib.pyplot as plt
plt.plot(learning_rate, Gx)
plt.title('tuong quan cua learning rate va gia tri toi uu')
# Out:
# Text(0.5, 1.0, 'tuong quan cua learning rate va gia tri toi uu')

# %% [markdown]
# >Nhận xét, khi càng tăng learning rate thì giá trị tối uu càng giảm, nhưng khi gần đạt đến 1 thì giá trị tối uư tại tăng lên, chứng tỏ giá trị tối ưu của bài này nằm khoảm 0 tới 0,95, nếu chọn quá thấp thì giá trị tối ưu sẽ quá lớn vì 100 vòng lập ko đủ để chạy tới giá trị tối ưu. vậy nen ta cần chọn learningrate hợp lý, ko quá lớn cũng ko quá nhỏ

# %% [markdown]
# 2.4. Ví dụ thực tế trong khoa học dữ liệu cần dùng gd, tính giá trị tối ưu trong việc truyền tin của hàm entropy đơn giản hơn

# %%
import numpy as np

# --- 1. Định nghĩa hàm mục tiêu và đạo hàm ---
# f(x) = x^2 + sin(x/2) + 2023x
def f(x):
    return x**2 + np.sin(x/2) + 2023*x

# Đạo hàm của f(x)
# f'(x) = 2x + (1/2)cos(x/2) + 2023
def gradient_f(x):
    return 2*x + 0.5 * np.cos(x/2) + 2023

# --- 2. Cài đặt thuật toán Gradient Descent ---
# Tham số đầu vào
x_start = 2024.0
learning_rate = 0.9
max_iterations = 100

x_current = x_start
print(f"Giá trị khởi đầu: x_0 = {x_start}")
print("-" * 40)

# Vòng lặp Gradient Descent
for k in range(max_iterations):
    # Tính gradient tại điểm hiện tại
    grad = gradient_f(x_current)
    
    # Cập nhật giá trị x mới theo công thức
    x_current = x_current - learning_rate * grad
    
    # In kết quả sau mỗi 10 vòng lặp để theo dõi
    if (k + 1) % 10 == 0:
        current_f_val = f(x_current)
        print(f"Vòng lặp {k+1}: x = {x_current:.6f}, f(x) = {current_f_val:.6f}")

print("-" * 40)
print(f"Kết quả sau {max_iterations} vòng lặp:")
print(f"  Giá trị x cuối cùng: {x_current:.6f}")
print(f"  Giá trị f(x) tương ứng: {f(x_current):.6f}")

# --- 3. Giải thích về Learning Rate ---
print("\n--- 3. Giải thích tầm quan trọng của Learning Rate ---")
print("Learning Rate (tốc độ học) là một tham số cực kỳ quan trọng trong Gradient Descent, quyết định độ dài của mỗi bước đi khi di chuyển về phía cực tiểu.")
print("- Nếu Learning Rate quá lớn: Thuật toán có thể 'nhảy' qua điểm tối ưu, không bao giờ hội tụ, hoặc thậm chí phân kỳ (đi ra xa vô cùng).")
print("- Nếu Learning Rate quá nhỏ: Thuật toán sẽ hội tụ rất chậm, cần rất nhiều vòng lặp để đạt được kết quả tốt.")
print("Việc lựa chọn Learning Rate tối ưu thường là một quá trình thử nghiệm. Có các phương pháp nâng cao hơn như Adam, RMSprop giúp tự điều chỉnh Learning Rate trong quá trình huấn luyện.")

# --- 4. Ví dụ thực tế về ứng dụng ---
print("\n--- 4. Ví dụ thực tế về ứng dụng của Gradient Descent ---")
print("Gradient Descent được sử dụng rộng rãi trong học máy và khoa học dữ liệu. Một ví dụ điển hình là trong:")
print("- Hồi quy tuyến tính (Linear Regression): Thuật toán này giúp tìm các hệ số tốt nhất cho đường hồi quy sao cho tổng sai số bình phương giữa các điểm dữ liệu và đường thẳng là nhỏ nhất.")
print("- Huấn luyện mạng nơ-ron (Neural Networks): Gradient Descent (cùng với thuật toán lan truyền ngược - backpropagation) được dùng để điều chỉnh các trọng số của mạng, giúp mạng học và đưa ra dự đoán chính xác hơn.")
# Out:
# Giá trị khởi đầu: x_0 = 2024.0
# ----------------------------------------
# Vòng lặp 10: x = -685.582318, f(x) = -916909.564273
# Vòng lặp 20: x = -977.186302, f(x) = -1021953.822958
# Vòng lặp 30: x = -1008.075114, f(x) = -1023121.502524
# Vòng lặp 40: x = -1010.756601, f(x) = -1023132.103398
# Vòng lặp 50: x = -1011.167900, f(x) = -1023132.350582
# Vòng lặp 60: x = -1011.238922, f(x) = -1023132.357872
# Vòng lặp 70: x = -1011.251083, f(x) = -1023132.358086
# Vòng lặp 80: x = -1011.253160, f(x) = -1023132.358092
# Vòng lặp 90: x = -1011.253515, f(x) = -1023132.358092
# Vòng lặp 100: x = -1011.253575, f(x) = -1023132.358092
# ----------------------------------------
# Kết quả sau 100 vòng lặp:
#   Giá trị x cuối cùng: -1011.253575
#   Giá trị f(x) tương ứng: -1023132.358092
#
# --- 3. Giải thích tầm quan trọng của Learning Rate ---
# Learning Rate (tốc độ học) là một tham số cực kỳ quan trọng trong Gradient Descent, quyết định độ dài của mỗi bước đi khi di chuyển về phía cực tiểu.
# ...

# %% [markdown]
# # TUI LAM

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- 1. Định nghĩa hàm mục tiêu và đạo hàm ---
def f(x):
    return x**2 + np.sin(x/2) + 2023*x

def df_dx(x):
    return 2*x + 0.5 * np.cos(x/2) + 2023

# --- 2. Thuật toán Gradient Descent ---
def gradient_descent_1d(f, df_dx, x_init, learning_rate, num_iterations, tolerance=1e-8):
    x = x_init
    history = {'x': [x], 'f': [f(x)], 'gradient': [df_dx(x)], 'step_size': []}
    
    for i in range(num_iterations):
        gradient = df_dx(x)
        if abs(gradient) < tolerance:
            print(f"Hội tụ tại vòng lặp {i+1}, gradient = {gradient:.2e}")
            break
            
        x_new = x - learning_rate * gradient
        step_size = abs(x_new - x)
        x = x_new
        
        history['x'].append(x)
        history['f'].append(f(x))
        history['gradient'].append(gradient)
        history['step_size'].append(step_size)
    
    return history

# --- 3. Thực thi bài toán ---
x_initial = 2024.0
alpha = 0.9
iterations = 100

history = gradient_descent_1d(f, df_dx, x_initial, alpha, iterations)

x_opt = history['x'][-1]  # nghiệm gần đúng
errors = [abs(x - x_opt) for x in history['x']]  # sai số tại mỗi vòng

# --- In kết quả ---
print(f"--- Kết quả sau {iterations} vòng lặp ---")
print(f"x cuối cùng: {x_opt:.6f}")
print(f"f(x cuối cùng): {f(x_opt):.6f}")

# --- 4. Vẽ đồ thị ---
iteration_indices = range(len(history['x']))

plt.figure(figsize=(12, 9))

# (1) f(x) theo số vòng lặp
plt.subplot(3, 1, 1)
plt.plot(iteration_indices, history['f'], marker='o', color='tab:blue')
plt.title('Giá trị hàm số f(x) qua các vòng lặp', fontsize=14)
plt.xlabel('Số vòng lặp')
plt.ylabel('f(x)')
plt.grid(True)

# (2) x theo số vòng lặp
plt.subplot(3, 1, 2)
plt.plot(iteration_indices, history['x'], marker='o', color='tab:orange')
plt.title('Giá trị x qua các vòng lặp', fontsize=14)
plt.xlabel('Số vòng lặp')
plt.ylabel('x')
plt.grid(True)

# (3) Sai số |x - x*| theo số vòng lặp
plt.subplot(3, 1, 3)
plt.plot(iteration_indices, errors, marker='o', color='tab:red')
plt.title('Sai số |x - x*| qua các vòng lặp', fontsize=14)
plt.xlabel('Số vòng lặp')
plt.ylabel('Sai số')
plt.yscale('log')  # dùng log scale để dễ nhìn sự giảm sai số
plt.grid(True)

plt.tight_layout()
plt.show()

# --- 5. Thông tin thêm ---
print("\n--- Chi tiết hội tụ ---")
print(f"x_0 = {history['x'][0]:.6f}, f(x_0) = {history['f'][0]:.6f}")
print(f"x_10 = {history['x'][10]:.6f}, f(x_10) = {history['f'][10]:.6f}")
print(f"x_50 = {history['x'][50]:.6f}, f(x_50) = {history['f'][50]:.6f}")
print(f"x_cuoi = {x_opt:.6f}, f(x_cuoi) = {f(x_opt):.6f}")



# --- 3️⃣ Thử nghiệm với các learning rate khác nhau ---
x_initial = 2024.0
iterations = 50
learning_rates = [0.001, 0.05, 1.0]
histories = {}

for lr in learning_rates:
    histories[lr] = gradient_descent_1d(f, df_dx, x_initial, lr, iterations)

# --- 4️⃣ Vẽ đồ thị so sánh ---
plt.figure(figsize=(12,6))

# a) Giá trị hàm f(x) theo số vòng lặp
plt.subplot(1, 2, 1)
for lr, hist in histories.items():
    plt.plot(hist['f'], marker='o', label=f'η = {lr}')
plt.title('Giá trị f(x) qua các vòng lặp', fontsize=13)
plt.xlabel('Số vòng lặp')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)

# b) Giá trị x qua các vòng lặp
plt.subplot(1, 2, 2)
for lr, hist in histories.items():
    plt.plot(hist['x'], marker='o', label=f'η = {lr}')
plt.title('Giá trị x qua các vòng lặp', fontsize=13)
plt.xlabel('Số vòng lặp')
plt.ylabel('x')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# --- 5️⃣ Phân tích kết quả ---
print("\n--- PHÂN TÍCH ẢNH HƯỞNG CỦA LEARNING RATE ---")
for lr, hist in histories.items():
    x_final = hist['x'][-1]
    f_final = hist['f'][-1]
    print(f"η = {lr:<6} → x_cuối ≈ {x_final:.6f}, f(x_cuối) ≈ {f_final:.6f}")

print("\n--- GIẢI THÍCH CHI TIẾT ---")
print("🔹 Khi η = 0.001 (rất nhỏ):")
print("   - Các bước cập nhật cực kỳ nhỏ, do đó thuật toán hội tụ chậm.")
print("   - f(x) giảm dần rất chậm, cần nhiều vòng lặp mới tới gần điểm tối ưu.")

print("🔹 Khi η = 0.05 (vừa phải):")
print("   - Các bước di chuyển hợp lý, giúp thuật toán hội tụ nhanh và ổn định.")
print("   - Đây là vùng learning rate ‘tốt’, đảm bảo tốc độ và ổn định.")

print("🔹 Khi η = 1.0 (quá lớn):")
print("   - Thuật toán di chuyển quá xa mỗi vòng, có thể vượt qua điểm tối ưu.")
print("   - Dẫn đến dao động hoặc phân kỳ (f(x) tăng lên thay vì giảm xuống).")

print("\n💡 KẾT LUẬN:")
print("   - Learning rate là tham số then chốt trong Gradient Descent.")
print("   - η quá nhỏ → chậm. η quá lớn → dao động hoặc không hội tụ.")
print("   - η tối ưu nên được chọn sao cho f(x) giảm đều, không dao động, thường qua thử nghiệm hoặc dùng kỹ thuật adaptive (Adam, RMSProp).")
# --- 4. Ví dụ thực tế về ứng dụng ---
print("\n--- 4. Ví dụ thực tế về ứng dụng của Gradient Descent ---")
print("Gradient Descent được sử dụng rộng rãi trong học máy và khoa học dữ liệu. Một ví dụ điển hình là trong:")
print("- Hồi quy tuyến tính (Linear Regression): Thuật toán này giúp tìm các hệ số tốt nhất cho đường hồi quy sao cho tổng sai số bình phương giữa các điểm dữ liệu và đường thẳng là nhỏ nhất.")
print("- Huấn luyện mạng nơ-ron (Neural Networks): Gradient Descent (cùng với thuật toán lan truyền ngược - backpropagation) được dùng để điều chỉnh các trọng số của mạng, giúp mạng học và đưa ra dự đoán chính xác hơn.")
# Out:
# --- Kết quả sau 100 vòng lặp ---
# x cuối cùng: -1011.253575
# f(x cuối cùng): -1023132.358092
# --- Chi tiết hội tụ ---
# x_0 = 2024.000000, f(x_0) = 8191128.396008
# x_10 = -685.582318, f(x_10) = -916909.564273
# x_50 = -1011.167900, f(x_50) = -1023132.350582
# x_cuoi = -1011.253575, f(x_cuoi) = -1023132.358092
# --- PHÂN TÍCH ẢNH HƯỞNG CỦA LEARNING RATE ---
# η = 0.001  → x_cuối ≈ 1734.859006, f(x_cuối) ≈ 6519355.881986
# η = 0.05   → x_cuối ≈ -995.897566, f(x_cuối) ≈ -1022889.814044
# η = 1.0    → x_cuối ≈ 2024.828361, f(x_cuối) ≈ 8196158.395173
#
# --- GIẢI THÍCH CHI TIẾT ---
# 🔹 Khi η = 0.001 (rất nhỏ):
#    - Các bước cập nhật cực kỳ nhỏ, do đó thuật toán hội tụ chậm.
#    - f(x) giảm dần rất chậm, cần nhiều vòng lặp mới tới gần điểm tối ưu.
# 🔹 Khi η = 0.05 (vừa phải):
#    - Các bước di chuyển hợp lý, giúp thuật toán hội tụ nhanh và ổn định.
#    - Đây là vùng learning rate ‘tốt’, đảm bảo tốc độ và ổn định.
# 🔹 Khi η = 1.0 (quá lớn):
# ...

# %% [markdown]
# ### Câu 3 (3 điểm)

# %% [markdown]
# Gọi $\gamma=\overline{\gamma_1\gamma_2\gamma_3\gamma_4\gamma_5\gamma_6\gamma_7\gamma_8}$ là mã số sinh viên của anh/chị. Đặt $\alpha=\gamma_7$ và $\beta=\sum_{i=1}^8\gamma_i$, xét bài toán tối ưu sau
# \begin{align}
# \min_{x=(x_1,x_2)\in \mathbb{R}^2} f(x)=\dfrac{1}{2}x_1^2+\dfrac{1}{2}x_2^2+(\alpha+1) x_2-\beta\quad (1)
# \end{align}
#
# 1. Hãy tìm $\alpha,\beta$ và giá trị tối ưu $p^*$ của bài toán (1).
#
# 2. 2. Sử dụng thuật toán Gradient Descent cho bài toán (1) với learning rate là $\dfrac{1}{\alpha+1}$ và điểm khởi tạo $x^{(0)}=(1,0)$, hãy tìm công thức cho điểm cập nhật $x^{(k)}$.

# %% [markdown]
# 1. Hãy tìm $\alpha,\beta$ và giá trị tối ưu $p^*$ của bài toán (1).

# %% [markdown]
# 2. Sử dụng thuật toán Gradient Descent cho bài toán (1) với learning rate là $\dfrac{1}{\alpha+1}$ và điểm khởi tạo $x^{(0)}=(1,0)$, hãy tìm công thức cho điểm cập nhật $x^{(k)}$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# ====================================
# 1️⃣ Thông tin sinh viên
# ====================================
gamma = [2, 3, 6, 3, 1, 9, 7, 1]
alpha = gamma[6]           # γ7
beta = sum(gamma)
print(f"α = {alpha}, β = {beta}")

# ====================================
# 2️⃣ Định nghĩa hàm và gradient
# ====================================
def f(x1, x2, alpha, beta):
    return 0.5*x1**2 + 0.5*x2**2 + (alpha+1)*x2 - beta

def grad_f(x1, x2, alpha):
    return np.array([x1, x2 + (alpha+1)])

# ====================================
# 3️⃣ Gradient Descent
# ====================================

eta = 1 / (alpha + 1)
print("\n=== CÔNG THỨC CẬP NHẬT (theo Gradient Descent) ===")
print(f"Learning rate (η) = 1/(α+1) = 1/{alpha+1} = {eta:.4f}")
print("Công thức tổng quát:")
print("  x₁^(k+1) = x₁^(k) - η * x₁^(k) = (1 - η) * x₁^(k)")
print("  x₂^(k+1) = x₂^(k) - η * (x₂^(k) + α + 1)")
print(f"Thay α = {alpha} và η = {eta:.4f} ta được:")
print(f"  x₁^(k+1) = (1 - {eta:.4f}) * x₁^(k) = {(1-eta):.4f} * x₁^(k)")
print(f"  x₂^(k+1) = (1 - {eta:.4f}) * x₂^(k) - η * ({alpha+1}) = {(1-eta):.4f} * x₂^(k) - 1")

# ====================================

x = np.array([1.0, 0.0])  # x^(0)
history = [x.copy()]
for k in range(10):       # ví dụ 10 vòng
    g = grad_f(x[0], x[1], alpha)
    x = x - eta * g
    history.append(x.copy())

# ====================================
# 4️⃣ In kết quả
# ====================================
x_star = np.array([0.0, -8.0])
p_star = f(x_star[0], x_star[1], alpha, beta)
print(f"\nĐiểm tối ưu x* = {x_star}")
print(f"Giá trị tối ưu p* = {p_star}")

print("\n--- Quá trình cập nhật x^(k) ---")
for i, xi in enumerate(history):
    print(f"k={i:2d}: x1={xi[0]:.6f}, x2={xi[1]:.6f}, f(x)={f(xi[0], xi[1], alpha, beta):.6f}")

# ====================================
# 5️⃣ Vẽ quỹ đạo hội tụ
# ====================================
history = np.array(history)
plt.figure(figsize=(8,4))
plt.plot(history[:,0], label='x1')
plt.plot(history[:,1], label='x2')
plt.title('Giá trị x1, x2 qua các vòng lặp (Gradient Descent)')
plt.xlabel('Số vòng lặp k')
plt.ylabel('Giá trị biến')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# α = 7, β = 32
#
# === CÔNG THỨC CẬP NHẬT (theo Gradient Descent) ===
# Learning rate (η) = 1/(α+1) = 1/8 = 0.1250
# Công thức tổng quát:
#   x₁^(k+1) = x₁^(k) - η * x₁^(k) = (1 - η) * x₁^(k)
#   x₂^(k+1) = x₂^(k) - η * (x₂^(k) + α + 1)
# Thay α = 7 và η = 0.1250 ta được:
#   x₁^(k+1) = (1 - 0.1250) * x₁^(k) = 0.8750 * x₁^(k)
#   x₂^(k+1) = (1 - 0.1250) * x₂^(k) - η * (8) = 0.8750 * x₂^(k) - 1
#
# Điểm tối ưu x* = [ 0. -8.]
# Giá trị tối ưu p* = -64.0
#
# --- Quá trình cập nhật x^(k) ---
# k= 0: x1=1.000000, x2=0.000000, f(x)=-31.500000
# k= 1: x1=0.875000, x2=-1.000000, f(x)=-39.117188
# k= 2: x1=0.765625, x2=-1.875000, f(x)=-44.949097
# k= 3: x1=0.669922, x2=-2.640625, f(x)=-49.414152
# k= 4: x1=0.586182, x2=-3.310547, f(x)=-52.832710
# k= 5: x1=0.512909, x2=-3.896729, f(x)=-55.450044
# k= 6: x1=0.448795, x2=-4.409637, f(x)=-57.453940
# k= 7: x1=0.392696, x2=-4.858433, f(x)=-58.988173
# k= 8: x1=0.343609, x2=-5.251129, f(x)=-60.162820
# ...

# %%
import numpy as np

# ======================================
# 1️⃣ Thông tin sinh viên
# ======================================
gamma = [2, 3, 6, 3, 1, 9, 7, 1]
alpha = gamma[6]           # γ7 = 7
beta = sum(gamma)          # Tổng 8 chữ số = 32

print(f"α = {alpha}, β = {beta}")

# ======================================
# 2️⃣ Định nghĩa hàm mục tiêu và gradient
# ======================================
def f(x):
    """Hàm mục tiêu f(x1, x2)"""
    x1, x2 = x
    return 0.5 * x1**2 + 0.5 * x2**2 + (alpha + 1)*x2 - beta

def grad_f(x):
    """Gradient của f(x1, x2)"""
    x1, x2 = x
    return np.array([x1, x2 + (alpha + 1)])

# ======================================
# 3️⃣ CÂU 1: Tự động tìm nghiệm tối ưu x* và giá trị tối ưu p*
# ======================================
# Giải phương trình ∇f(x) = 0
# <=> x1 = 0 và x2 = -(α + 1)
def find_optimum(alpha, beta):
    """
    Giải nghiệm tối ưu x* và p* cho hàm f(x1,x2)
    Returns:
        x_star: vector nghiệm tối ưu [x1*, x2*]
        p_star: giá trị tối ưu f(x*)
    """
    # có thể mở rộng cho các hàm khác bằng cách dùng scipy.optimize.solve, nhưng ở đây gradient = 0 đơn giản
    A = np.array([[1, 0], [0, 1]])  # Hệ số gradient tuyến tính: [x1, x2 + (α+1)]
    b = np.array([0, -(alpha + 1)]) # nghiệm theo gradient = 0
    x_star = np.linalg.solve(np.eye(2), b)  # giải hệ đơn giản
    p_star = f(x_star)
    return x_star, p_star

x_star, p_star = find_optimum(alpha, beta)
print("\n--- CÂU 1: KẾT QUẢ TỰ TÍNH ---")
print(f"x* = {x_star}")
print(f"p* = f(x*) = {p_star:.6f}")

# ======================================
# 4️⃣ Thuật toán Gradient Descent (Câu 2)
# ======================================
def gradient_descent_2d(f, grad_f, x_init, learning_rate, num_iterations, tolerance=1e-8):
    """
    Thuật toán Gradient Descent tổng quát cho hàm 2 biến
    """
    x = x_init
    history = {'x': [x.copy()], 'f': [f(x)], 'gradient': [grad_f(x)], 'step_size': []}
    
    for i in range(num_iterations):
        g = grad_f(x)
        if np.linalg.norm(g) < tolerance:
            print(f"Hội tụ tại vòng lặp {i+1}, ||∇f|| = {np.linalg.norm(g):.2e}")
            break
        x_new = x - learning_rate * g
        step_size = np.linalg.norm(x_new - x)
        x = x_new
        history['x'].append(x.copy())
        history['f'].append(f(x))
        history['gradient'].append(g)
        history['step_size'].append(step_size)
    return history

# ======================================
# 5️⃣ Chạy thuật toán Gradient Descent
# ======================================
eta = 1 / (alpha + 1)
x0 = np.array([1.0, 0.0])
iterations = 50

print("\n--- CÔNG THỨC CẬP NHẬT ---")
print(f"η = 1 / (α + 1) = 1 / ({alpha + 1}) = {eta:.4f}")
print("Công thức: x^{(k+1)} = x^{(k)} - η ∇f(x^{(k)})")

history = gradient_descent_2d(f, grad_f, x0, eta, iterations)

x_opt = history['x'][-1]
f_opt = f(x_opt)

print("\n--- CÂU 2: KẾT QUẢ THUẬT TOÁN ---")
print(f"x tối ưu (theo GD) ≈ {x_opt}")
print(f"f(x*) ≈ {f_opt:.6f}")

# ======================================
# 6️⃣ Một vài vòng lặp tiêu biểu
# ======================================
print("\n--- Một vài vòng lặp tiêu biểu ---")
for i in [0, 1, 2, 5, 10, 20, len(history['x'])-1]:
    x_i = history['x'][i]
    print(f"Vòng {i:2d}: x = {x_i}, f(x) = {f(x_i):.6f}")
# Out:
# α = 7, β = 32
#
# --- CÂU 1: KẾT QUẢ TỰ TÍNH ---
# x* = [ 0. -8.]
# p* = f(x*) = -64.000000
#
# --- CÔNG THỨC CẬP NHẬT ---
# η = 1 / (α + 1) = 1 / (8) = 0.1250
# Công thức: x^{(k+1)} = x^{(k)} - η ∇f(x^{(k)})
#
# --- CÂU 2: KẾT QUẢ THUẬT TOÁN ---
# x tối ưu (theo GD) ≈ [ 1.26009315e-03 -7.98991925e+00]
# f(x*) ≈ -63.999948
#
# --- Một vài vòng lặp tiêu biểu ---
# Vòng  0: x = [1. 0.], f(x) = -31.500000
# Vòng  1: x = [ 0.875 -1.   ], f(x) = -39.117188
# Vòng  2: x = [ 0.765625 -1.875   ], f(x) = -44.949097
# Vòng  5: x = [ 0.51290894 -3.89672852], f(x) = -55.450044
# Vòng 10: x = [ 0.26307558 -5.89539539], f(x) = -61.750715
# Vòng 20: x = [ 0.06920876 -7.44632993], f(x) = -63.844330
# Vòng 50: x = [ 1.26009315e-03 -7.98991925e+00], f(x) = -63.999948

# %%
pip install autograd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # . CHot

# %% [markdown]
# Gọi $\gamma=\overline{\gamma_1\gamma_2\gamma_3\gamma_4\gamma_5\gamma_6\gamma_7\gamma_8}$ là mã số sinh viên của anh/chị. Đặt $\alpha=\gamma_7$ và $\beta=\sum_{i=1}^8\gamma_i$, xét bài toán tối ưu sau
# \begin{align}
# \min_{x=(x_1,x_2)\in \mathbb{R}^2} f(x)=\dfrac{1}{2}x_1^2+\dfrac{1}{2}x_2^2+(\alpha+1) x_2-\beta\quad (1)
# \end{align}
#
# 1. Hãy tìm $\alpha,\beta$ và giá trị tối ưu $p^*$ của bài toán (1).
#
# 2. 2. Sử dụng thuật toán Gradient Descent cho bài toán (1) với learning rate là $\dfrac{1}{\alpha+1}$ và điểm khởi tạo $x^{(0)}=(1,0)$, hãy tìm công thức cho điểm cập nhật $x^{(k)}$.
#
# 3. Gọi $x^*$ là điểm tối ưu của (1), hãy vẽ đồ thị biểu thị cho sai số $\text{err}_k=\|\nabla f(x^*)-\nabla f(x^{(k)})\|_2^2$. Từ đó anh/chị rút ra được kết luận gì?
# 4. Hãy tìm learning rate trong thuật toán Gradient Descent của bài toán (1) theo phương pháp exact line search. Từ đó rút ra nhận xét cho các điểm cập nhật $x^{(k)}$.

# %%
import numpy as np
from autograd import grad
from autograd import numpy as anp
from scipy.optimize import root

# ======================================
# 1️⃣ Thông tin sinh viên
# ======================================
gamma = [2, 3, 6, 3, 1, 9, 7, 1]
alpha = gamma[6]           # γ7 = 7
beta = sum(gamma)          # Tổng 8 chữ số = 32

print(f"α = {alpha}, β = {beta}")

# ======================================
# 2️⃣ Định nghĩa hàm mục tiêu (dùng autograd)
# ======================================
def f(x):
    """Hàm mục tiêu f(x1, x2)"""
    x1, x2 = x[0], x[1]
    return 0.5 * x1**2 + 0.5 * x2**2 + (alpha + 1)*x2 - beta

# Tạo gradient tự động bằng autograd
grad_f = grad(lambda x: f(x))  # đạo hàm tự động của f(x) theo vector x

# ======================================
# 3️⃣ CÂU 1: Tự động tìm nghiệm tối ưu x* và giá trị tối ưu p*
# ======================================
#"""
#def find_optimum(grad_f, f, x0):
    
    #Giải nghiệm tối ưu x* và p* bằng cách tìm nghiệm của ∇f(x) = 0
    #Args:
        #grad_f: hàm gradient (autograd)
       # f: hàm mục tiêu
       # x0: điểm khởi tạo ban đầu
    #Returns:
       # x_star: vector nghiệm tối ưu
       # p_star: giá trị f(x*) tại nghiệm
    
    # Dùng scipy.optimize.root để giải hệ ∇f(x)=0
    #sol = root(lambda x: grad_f(x), x0)
    #x_star = sol.x
    #p_star = f(x_star)
    #return x_star, p_star
#"""
from scipy.optimize import minimize

def find_optimum(grad_f, f):
    """
    Tìm x* và p* bằng cách tối thiểu hóa ||∇f(x)||²
    """
    x0 = np.zeros(2)
    # định nghĩa hàm phụ
    def g_norm2(x): 
        g = grad_f(x)
        return np.sum(g**2)
    
    res = minimize(g_norm2, x0, method='BFGS')
    x_star = res.x
    p_star = f(x_star)
    return x_star, p_star
# Gọi hàm tìm nghiệm
x_star, p_star = find_optimum(grad_f, f)

print("\n--- CÂU 1: KẾT QUẢ TỰ TÍNH (dùng autograd + scipy) ---")
print(f"x* = {x_star}")
print(f"p* = f(x*) = {p_star:.6f}")

# ======================================
# 4️⃣ Thuật toán Gradient Descent (Câu 2)
# ======================================
def gradient_descent_2d(f, grad_f, x_init, learning_rate, num_iterations, tolerance=1e-8):
    """
    Thuật toán Gradient Descent tổng quát cho hàm 2 biến
    """
    x = x_init
    history = {'x': [x.copy()], 'f': [f(x)], 'gradient': [grad_f(x)], 'step_size': [], 'grad_norm2': [np.linalg.norm(grad_f(x))**2]}
    
    for i in range(num_iterations):
        g = grad_f(x)
        if np.linalg.norm(g) < tolerance:
            print(f"Hội tụ tại vòng lặp {i+1}, ||∇f|| = {np.linalg.norm(g):.2e}")
            break
        x_new = x - learning_rate * g
        step_size = np.linalg.norm(x_new - x)
        x = x_new
        history['x'].append(x.copy())
        history['f'].append(f(x))
        history['gradient'].append(g)
        history['step_size'].append(step_size)
        history['grad_norm2'].append(np.linalg.norm(grad_f(x))**2)
    return history

# ======================================
# 5️⃣ Chạy thuật toán Gradient Descent
# ======================================
eta = 1 / (alpha + 1)
x0 = np.array([1.0, 0.0])
iterations = 50

print("\n--- CÔNG THỨC CẬP NHẬT ---")
print(f"η = 1 / (α + 1) = 1 / ({alpha + 1}) = {eta:.4f}")
print("Công thức: x^{(k+1)} = x^{(k)} - η ∇f(x^{(k)})")

history = gradient_descent_2d(f, grad_f, x0, eta, iterations)

x_opt = history['x'][-1]
f_opt = f(x_opt)

print("\n--- CÂU 2: KẾT QUẢ THUẬT TOÁN ---")
print(f"x tối ưu (theo GD) ≈ {x_opt}")
print(f"f(x*) ≈ {f_opt:.6f}")

# ======================================
# 6️⃣ CÂU 3: Vẽ đồ thị sai số err_k = ||∇f(x*) - ∇f(xk)||²
# ======================================
err_k = np.array(history['grad_norm2'])  # vì ∇f(x*)=0
plt.figure(figsize=(8,5))
plt.plot(err_k, marker='o', color='tab:red')
plt.yscale('log')
plt.xlabel("Số vòng lặp k")
plt.ylabel(r"$\mathrm{err}_k = ||\nabla f(x^*) - \nabla f(x^{(k)})||_2^2$")
plt.title("Biểu đồ hội tụ sai số gradient (theo log scale)")
plt.grid(True)
plt.show()

# Sai số ban đầu và cuối
err_start = err_k[0]
err_end = err_k[-1]

# Tỷ lệ giảm sai số (log10)
reduction_ratio = err_end / err_start
log_drop = np.log10(err_start / err_end) if err_end > 0 else np.inf

print("\n--- CÂU 3: KẾT LUẬN ---")
print(f"Sai số ban đầu: {err_start:.6e}")
print(f"Sai số cuối cùng: {err_end:.6e}")
print(f"Tỷ lệ giảm sai số: {reduction_ratio:.6e}")
print(f"Mức giảm theo log10: {log_drop:.2f} bậc độ lớn")

if err_end < 1e-6:
    print("✅ Kết luận: Sai số gradient giảm rất mạnh → Thuật toán hội tụ tốt về x*.")
elif err_end < 1e-3:
    print("⚠️ Kết luận: Sai số giảm chậm nhưng vẫn hội tụ dần → Cần nhiều vòng lặp hơn hoặc learning rate lớn hơn.")
else:
    print("❌ Kết luận: Sai số chưa giảm đáng kể → Có thể learning rate quá nhỏ hoặc chưa hội tụ.")

# ======================================

# ======================================
# 6️⃣ Một vài vòng lặp tiêu biểu
# ======================================
print("\n--- Một vài vòng lặp tiêu biểu ---")
for i in [0, 1, 2, 5, 10, 20, len(history['x'])-1]:
    x_i = history['x'][i]
    print(f"Vòng {i:2d}: x = {x_i}, f(x) = {f(x_i):.6f}")



# ======================================
# ======================================
# 7️⃣ CÂU 4: EXACT LINE SEARCH
# ======================================
from scipy.optimize import minimize_scalar

def exact_line_search(f, grad_f, xk):
    """
    Thực hiện Exact Line Search để tìm learning rate tối ưu η*
    cho hàm bất kỳ tại điểm xk.
    """
    gk = grad_f(xk)
    def phi(eta):
        return f(xk - eta * gk)
    res = minimize_scalar(phi, bounds=(0, 2), method='bounded')
    return res.x

# Tính η_exact tại điểm khởi tạo
eta_exact = exact_line_search(f, grad_f, x0)

print("\n--- CÂU 4: EXACT LINE SEARCH ---")
print(f"η (Exact Line Search) = {eta_exact:.6f}")
print(f"η (Cố định theo đề)   = {eta:.6f}")

# Nhận xét:
if abs(eta_exact - eta) < 1e-2:
    print("✅ Nhận xét: η_exact gần với η cố định → tốc độ hội tụ ổn định và hợp lý.")
elif eta_exact > eta:
    print("⚠️ Nhận xét: η_exact lớn hơn η cố định → ta có thể tăng learning rate để hội tụ nhanh hơn.")
else:
    print("⚠️ Nhận xét: η_exact nhỏ hơn η cố định → learning rate hiện tại hơi lớn, dễ dao động quanh nghiệm.")
# Out:
# α = 7, β = 32
#
# --- CÂU 1: KẾT QUẢ TỰ TÍNH (dùng autograd + scipy) ---
# x* = [ 0.         -8.00000033]
# p* = f(x*) = -64.000000
#
# --- CÔNG THỨC CẬP NHẬT ---
# η = 1 / (α + 1) = 1 / (8) = 0.1250
# Công thức: x^{(k+1)} = x^{(k)} - η ∇f(x^{(k)})
#
# --- CÂU 2: KẾT QUẢ THUẬT TOÁN ---
# x tối ưu (theo GD) ≈ [ 1.26009315e-03 -7.98991925e+00]
# f(x*) ≈ -63.999948
# --- CÂU 3: KẾT LUẬN ---
# Sai số ban đầu: 6.500000e+01
# Sai số cuối cùng: 1.032093e-04
# Tỷ lệ giảm sai số: 1.587835e-06
# Mức giảm theo log10: 5.80 bậc độ lớn
# ⚠️ Kết luận: Sai số giảm chậm nhưng vẫn hội tụ dần → Cần nhiều vòng lặp hơn hoặc learning rate lớn hơn.
#
# --- Một vài vòng lặp tiêu biểu ---
# Vòng  0: x = [1. 0.], f(x) = -31.500000
# Vòng  1: x = [ 0.875 -1.   ], f(x) = -39.117188
# Vòng  2: x = [ 0.765625 -1.875   ], f(x) = -44.949097
# Vòng  5: x = [ 0.51290894 -3.89672852], f(x) = -55.450044
# Vòng 10: x = [ 0.26307558 -5.89539539], f(x) = -61.750715
# ...

# %% [markdown]
# ## ------------------------------------------------ Hết -----------------------------------------------

# %% [markdown]
# ### Lưu ý: sinh viên không được sử dụng internet. Giám thị không giải thích gì thêm.
